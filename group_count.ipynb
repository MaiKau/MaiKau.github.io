# %% [markdown]
# <h1><center>表內</center></h1>

# %%
import pandas as pd
import sqlite3

# 連sqlite
conn = sqlite3.connect('BiobankData.db')

def count_ids(table_name, group_name, disease_codes):
    id_column = None
    other_columns = []

    if table_name == 'CRLF':
        id_column = 'id'
        other_columns = ['site']
    elif table_name == 'TOTFAE':
        id_column = 'd3'
        other_columns = ['d19', 'd20', 'd21', 'd22', 'd23']
    elif table_name == 'TOTFBE':
        id_column = 'd3'
        other_columns = ['d25', 'd26', 'd27', 'd28', 'd29']

    # 構建 SQL 查詢
    query = f"SELECT DISTINCT {id_column} FROM {table_name} WHERE {' OR '.join([f'{col} IN {tuple(disease_codes)}' for col in other_columns])}"
    
    # 使用 pd.read_sql_query 讀取結果
    result = pd.read_sql_query(query, conn)
    
    # 返回結果的 DataFrame
    result_df = pd.DataFrame({'Table_Name': [table_name],
                              'Group_name': [group_name],
                              'Id_unique_count': [len(result)]})

    return result_df

#疾病code定義
oral_cancer_codes = ["C00","C000","C001","C002","C003","C004","C005","C006","C008","C009","C01","C02","C020","C021","C022",
                     "C023","C024","C028","C029","C03","C030","C031","C039","C04","C040","C041","C048","C049","C05","C050",
                     "C051","C052","C058","C059","C06","C060","C061","C062","C068","C0680","C0689","C069","C09","C090","C091",
                     "C098","C099","C10","C100","C101","C102","C103","C104","C108","C109","C12","C13","C130","C131","C132",
                     "C138","C139","C14","C140","C142","C148"]

leukemia_codes = ["C42","C420","C421","C91","C910","C9100","C9101","C9102","C911","C9110","C9111","C9112","C913","C9130",
                  "C9131","C9132","C914","C9140","C9141","C9142","C915","C9150","C9151","C9152","C916","C9160","C9161",
                  "C9162","C919","C9190","C9191","C9192","C91A","C91A0","C91A1","C91A2","C91Z","C91Z0","C91Z1","C91Z2",
                  "C92","C920","C9200","C9201","C9202","C921","C9210","C9211","C9212","C922","C9220","C9221","C9222",
                  "C923","C9230","C9231","C9232","C924","C9240","C9241","C9242","C925","C9250","C9251","C9252","C926",
                  "C9260","C9261","C9262","C929","C9290","C9291","C9292","C92A","C92A0","C92A1","C92A2","C92Z","C92Z0",
                  "C92Z1","C92Z2","C93","C930","C9300","C9301","C9302","C931","C9310","C9311","C9312","C933","C9330",
                  "C9331","C9332","C939","C9390","C9391","C9392","C93Z","C93Z0","C93Z1","C93Z2","C94","C940","C9400",
                  "C9401","C9402","C942","C9420","C9421","C9422","C943","C9430","C9431","C9432","C944","C9440","C9441",
                  "C9442","C946","C948","C9480","C9481","C9482","C95","C950","C9500","C9501","C9502","C951","C9510",
                  "C9511","C9512","C959","C9590","C9591","C9592"]

cholangiocarcinoma_codes = ["C24","C240","C241","C248","C249"]


liver_cancer_codes = ["C22","C220","C221","C222","C223","C224","C227","C228","C229"]


breast_cancer_codes = ["C50","C500","C5001","C50011","C50012","C50019","C5002","C50021","C50022","C50029","C501",
                       "C5011","C50111","C50112","C50119","C5012","C50121","C50122","C50129","C502","C5021","C50211",
                       "C50212","C50219","C5022","C50221","C50222","C50229","C503","C5031","C50311","C50312","C50319",
                       "C5032","C50321","C50322","C50329","C504","C5041","C50411","C50412","C50419","C5042","C50421",
                       "C50422","C50429","C505","C5051","C50511","C50512","C50519","C5052","C50521","C50522","C50529",
                       "C506","C5061","C50611","C50612","C50619","C5062","C50621","C50622","C50629","C508","C5081",
                       "C50811","C50812","C50819","C5082","C50821","C50822","C50829","C509","C5091","C50911","C50912",
                       "C50919","C5092","C50921","C50922","C50929"]


lung_cancer_codes = ["C33","C34","C340","C3400","C3401","C3402","C341","C3410","C3411","C3412","C342","C343","C3430",
                     "C3431","C3432","C348","C3480","C3481","C3482","C349","C3490","C3491","C3492"]

stomach_cancer_codes = ["C16","C160","C161","C162","C163","C164","C165","C166","C168","C169"]

esophageal_cancer_codes = ["C15","C153","C154","C155","C158","C159"]

pancreatic_cancer_codes = ["C25","C250","C251","C252","C253","C254","C257","C258","C259"]

colon_cancer_codes = ["C17","C170","C171","C172","C173","C178","C179","C18","C180","C181","C182","C183","C184","C185",
                      "C186","C187","C188","C189","C19","C20","C21","C210","C211","C212","C218"]

gallbladder_cancer_codes = ["C23","for_tuple_fill"]

# 呼叫count_ids
result_df = pd.concat([count_ids('CRLF', '口腔癌群組', oral_cancer_codes),
                       count_ids('TOTFAE', '口腔癌群組', oral_cancer_codes),
                       count_ids('TOTFBE', '口腔癌群組', oral_cancer_codes),
                       count_ids('CRLF', '白血病群組', leukemia_codes),
                       count_ids('TOTFAE', '白血病群組', leukemia_codes),
                       count_ids('TOTFBE', '白血病群組', leukemia_codes),
                       count_ids('CRLF', '肝外膽管癌群組', cholangiocarcinoma_codes),
                       count_ids('TOTFAE', '肝外膽管癌群組', cholangiocarcinoma_codes),
                       count_ids('TOTFBE', '肝外膽管癌群組', cholangiocarcinoma_codes),
                       count_ids('CRLF', '肝癌群組', liver_cancer_codes),
                       count_ids('TOTFAE', '肝癌群組', liver_cancer_codes),
                       count_ids('TOTFBE', '肝癌群組', liver_cancer_codes),
                       count_ids('CRLF', '乳癌群組', breast_cancer_codes),
                       count_ids('TOTFAE', '乳癌群組', breast_cancer_codes),
                       count_ids('TOTFBE', '乳癌群組', breast_cancer_codes),
                       count_ids('CRLF', '肺癌群組', lung_cancer_codes),
                       count_ids('TOTFAE', '肺癌群組', lung_cancer_codes),
                       count_ids('TOTFBE', '肺癌群組', lung_cancer_codes),
                       count_ids('CRLF', '胃癌群組', stomach_cancer_codes),
                       count_ids('TOTFAE', '胃癌群組', stomach_cancer_codes),
                       count_ids('TOTFBE', '胃癌群組', stomach_cancer_codes),
                       count_ids('CRLF', '食道癌群組', esophageal_cancer_codes),
                       count_ids('TOTFAE', '食道癌群組', esophageal_cancer_codes),
                       count_ids('TOTFBE', '食道癌群組', esophageal_cancer_codes),
                       count_ids('CRLF', '胰臟癌群組', pancreatic_cancer_codes),
                       count_ids('TOTFAE', '胰臟癌群組', pancreatic_cancer_codes),
                       count_ids('TOTFBE', '胰臟癌群組', pancreatic_cancer_codes),
                       count_ids('CRLF', '腸癌群組', colon_cancer_codes),
                       count_ids('TOTFAE', '腸癌群組', colon_cancer_codes),
                       count_ids('TOTFBE', '腸癌群組', colon_cancer_codes),
                       count_ids('CRLF', '膽囊癌群組', gallbladder_cancer_codes),
                       count_ids('TOTFAE', '膽囊癌群組', gallbladder_cancer_codes),
                       count_ids('TOTFBE', '膽囊癌群組', gallbladder_cancer_codes)])

# 使用pivot_table旋轉表格
result_df = result_df.pivot_table(index='Group_name', columns='Table_Name', values='Id_unique_count', aggfunc='sum', fill_value=0)

# 重置索引
result_df = result_df.reset_index()
result_df.columns.name = None

# 顯示結果
conn.close()
result_df
# Out:
#    Group_name  CRLF  TOTFAE  TOTFBE
# 0        乳癌群組    78      77      79
# 1       口腔癌群組     0       0       0
# 2       白血病群組     0       0       0
# 3     肝外膽管癌群組     0       0       0
# 4        肝癌群組     0       0       0
# 5        肺癌群組     1       1       0
# 6        胃癌群組     0       0       0
# 7       胰臟癌群組     0       0       0
# 8        腸癌群組     1       3       2
# 9       膽囊癌群組     0       0       0
# 10      食道癌群組     1       1       1

# %% [markdown]
# <h1><center>表間</center></h1>

# %%
import pandas as pd
import sqlite3

# 連接到現有的 SQLite 資料庫
conn = sqlite3.connect('BiobankData.db')

def get_unique_ids(table_name, group_name, disease_codes):
    id_column = None
    other_columns = []

    if table_name == 'CRLF':
        id_column = 'id'
        other_columns = ['site']
    elif table_name == 'TOTFAE':
        id_column = 'd3'
        other_columns = ['d19', 'd20', 'd21', 'd22', 'd23']
    elif table_name == 'TOTFBE':
        id_column = 'd3'
        other_columns = ['d25', 'd26', 'd27', 'd28', 'd29']

    # 構建 SQL 查詢
    query = f"SELECT DISTINCT {id_column} FROM {table_name} WHERE {' OR '.join([f'{col} IN {tuple(disease_codes)}' for col in other_columns])}"
    
    # 使用 pd.read_sql_query 讀取結果
    result = pd.read_sql_query(query, conn)
    
    return result[id_column]

# 查找結果
disease_codes = ["C50","C500","C5001","C50011","C50012","C50019","C5002","C50021","C50022","C50029","C501",
                "C5011","C50111","C50112","C50119","C5012","C50121","C50122","C50129","C502","C5021","C50211",
                "C50212","C50219","C5022","C50221","C50222","C50229","C503","C5031","C50311","C50312","C50319",
                "C5032","C50321","C50322","C50329","C504","C5041","C50411","C50412","C50419","C5042","C50421",
                "C50422","C50429","C505","C5051","C50511","C50512","C50519","C5052","C50521","C50522","C50529",
                "C506","C5061","C50611","C50612","C50619","C5062","C50621","C50622","C50629","C508","C5081",
                "C50811","C50812","C50819","C5082","C50821","C50822","C50829","C509","C5091","C50911","C50912",
                "C50919","C5092","C50921","C50922","C50929"]

group_name = '乳癌群組'

# 取得三個表格的唯一 ID
unique_ids_crlf = get_unique_ids('CRLF', group_name, disease_codes)
unique_ids_totfae = get_unique_ids('TOTFAE', group_name, disease_codes)
unique_ids_totfbe = get_unique_ids('TOTFBE', group_name, disease_codes)

# 合併三個表格的唯一 ID
unique_ids_combined = pd.concat([unique_ids_crlf, unique_ids_totfae, unique_ids_totfbe])

# 計算唯一 ID 數量
result_df = pd.DataFrame({
    'Group_name': [group_name],
    'Id_unique_count': [unique_ids_combined.nunique()]
})

# 顯示結果
conn.close()
result_df
# Out:
#   Group_name  Id_unique_count
# 0       乳癌群組               80

# %% [markdown]
# <h1><center>混合(精準搜尋)</center></h1>

# %%
import pandas as pd
import sqlite3

# 連接到現有的 SQLite 資料庫
conn = sqlite3.connect('BiobankData.db')

# 定義群組列表和相應的疾病代碼
group_disease_mapping = {
    '口腔癌群組': ["C00","C000","C001","C002","C003","C004","C005","C006","C008","C009","C01","C02","C020",
              "C021","C022","C023","C024","C028","C029","C03","C030","C031","C039","C04","C040","C041",
              "C048","C049","C05","C050","C051","C052","C058","C059","C06","C060","C061","C062","C068",
              "C0680","C0689","C069","C09","C090","C091","C098","C099","C10","C100","C101","C102","C103",
              "C104","C108","C109","C12","C13","C130","C131","C132","C138","C139","C14","C140","C142","C148"],
    
    '白血病群組': ["C42","C420","C421","C91","C910","C9100","C9101","C9102","C911","C9110","C9111","C9112",
             "C913","C9130","C9131","C9132","C914","C9140","C9141","C9142","C915","C9150","C9151","C9152",
             "C916","C9160","C9161","C9162","C919","C9190","C9191","C9192","C91A","C91A0","C91A1","C91A2",
             "C91Z","C91Z0","C91Z1","C91Z2","C92","C920","C9200","C9201","C9202","C921","C9210","C9211",
             "C9212","C922","C9220","C9221","C9222","C923","C9230","C9231","C9232","C924","C9240","C9241",
             "C9242","C925","C9250","C9251","C9252","C926","C9260","C9261","C9262","C929","C9290","C9291",
             "C9292","C92A","C92A0","C92A1","C92A2","C92Z","C92Z0","C92Z1","C92Z2","C93","C930","C9300",
             "C9301","C9302","C931","C9310","C9311","C9312","C933","C9330","C9331","C9332","C939","C9390",
             "C9391","C9392","C93Z","C93Z0","C93Z1","C93Z2","C94","C940","C9400","C9401","C9402","C942",
             "C9420","C9421","C9422","C943","C9430","C9431","C9432","C944","C9440","C9441","C9442","C946",
             "C948","C9480","C9481","C9482","C95","C950","C9500","C9501","C9502","C951","C9510","C9511",
             "C9512","C959","C9590","C9591","C9592"],
    
    '肝外膽管癌群組': ["C24","C240","C241","C248","C249"],
    
    '肝癌群組': ["C22","C220","C221","C222","C223","C224","C227","C228","C229"],
    
    '乳癌群組': ["C50","C500","C5001","C50011","C50012","C50019","C5002","C50021","C50022","C50029","C501",
             "C5011","C50111","C50112","C50119","C5012","C50121","C50122","C50129","C502","C5021","C50211",
             "C50212","C50219","C5022","C50221","C50222","C50229","C503","C5031","C50311","C50312","C50319",
             "C5032","C50321","C50322","C50329","C504","C5041","C50411","C50412","C50419","C5042","C50421",
             "C50422","C50429","C505","C5051","C50511","C50512","C50519","C5052","C50521","C50522","C50529",
             "C506","C5061","C50611","C50612","C50619","C5062","C50621","C50622","C50629","C508","C5081",
             "C50811","C50812","C50819","C5082","C50821","C50822","C50829","C509","C5091","C50911","C50912",
             "C50919","C5092","C50921","C50922","C50929"],
    
    '肺癌群組': ["C33","C34","C340","C3400","C3401","C3402","C341","C3410","C3411","C3412","C342","C343","C3430",
             "C3431","C3432","C348","C3480","C3481","C3482","C349","C3490","C3491","C3492"],
    
    '胃癌群組': ["C16","C160","C161","C162","C163","C164","C165","C166","C168","C169"],
    
    '食道癌群組': ["C15","C153","C154","C155","C158","C159"],
    
    '胰臟癌群組': ["C25","C250","C251","C252","C253","C254","C257","C258","C259"],
    
    '腸癌群組': ["C17","C170","C171","C172","C173","C178","C179","C18","C180","C181","C182","C183","C184",
             "C185","C186","C187","C188","C189","C19","C20","C21","C210","C211","C212","C218"],
    
    '膽囊癌群組': ["C23","for_tuple_fill"]

}

def get_unique_ids(table_name, group_name, disease_codes):
    id_column = None
    other_columns = []

    if table_name == 'CRLF':
        id_column = 'id'
        other_columns = ['site']
    elif table_name == 'TOTFAE':
        id_column = 'd3'
        other_columns = ['d19', 'd20', 'd21', 'd22', 'd23']
    elif table_name == 'TOTFBE':
        id_column = 'd3'
        other_columns = ['d25', 'd26', 'd27', 'd28', 'd29']

    # 構建 SQL 查詢
    query = f"SELECT DISTINCT {id_column} FROM {table_name} WHERE {' OR '.join([f'{col} IN {tuple(disease_codes)}' for col in other_columns])}"

    # 使用 pd.read_sql_query 讀取結果
    result = pd.read_sql_query(query, conn)
    
    return result[id_column]

# 初始化結果 DataFrame
result_df = pd.DataFrame(columns=['Group_name', 'CRLF_unique_id', 'TOTFAE_unique_id', 'TOTFBE__unique_id', 'MIX_unique_count'])

# 查找結果
for group_name, disease_codes in group_disease_mapping.items():
    CRLF_unique_id = get_unique_ids('CRLF', group_name, disease_codes)
    TOTFAE_unique_id = get_unique_ids('TOTFAE', group_name, disease_codes)
    TOTFBE__unique_id = get_unique_ids('TOTFBE', group_name, disease_codes)
    MIX_unique_count = pd.concat([CRLF_unique_id, TOTFAE_unique_id, TOTFBE__unique_id])

    # 將結果添加到結果 DataFrame
    result_df = result_df.append({
        'Group_name': group_name,
        'CRLF_unique_id': len(CRLF_unique_id),
        'TOTFAE_unique_id': len(TOTFAE_unique_id),
        'TOTFBE__unique_id': len(TOTFBE__unique_id),
        'MIX_unique_count': MIX_unique_count.nunique()
    }, ignore_index=True)

# 顯示結果
conn.close()
result_df
# Out:
#    Group_name CRLF_unique_id TOTFAE_unique_id TOTFBE__unique_id  \
# 0       口腔癌群組              0                0                 0
# 1       白血病群組              0                0                 0
# 2     肝外膽管癌群組              0                0                 0
# 3        肝癌群組              0                0                 0
# 4        乳癌群組             78               77                79
# 5        肺癌群組              1                1                 0
# 6        胃癌群組              0                0                 0
# 7       食道癌群組              1                1                 1
# 8       胰臟癌群組              0                0                 0
# 9        腸癌群組              1                3                 2
# 10      膽囊癌群組              0                0                 0
#
#    MIX_unique_count
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                80
# 5                 1
# 6                 0
# 7                 1
# 8                 0
# 9                 3
# 10                0

# %% [markdown]
# <h1><center>混合(模糊搜尋)</center></h1>

# %%
import pandas as pd
import sqlite3

# 連接到現有的 SQLite 資料庫
conn = sqlite3.connect('BiobankData.db')

# 定義群組列表和相應的疾病代碼
group_disease_mapping = {
    '口腔癌群組': ["C00","C000","C001","C002","C003","C004","C005","C006","C008","C009","C01","C02","C020",
              "C021","C022","C023","C024","C028","C029","C03","C030","C031","C039","C04","C040","C041",
              "C048","C049","C05","C050","C051","C052","C058","C059","C06","C060","C061","C062","C068",
              "C0680","C0689","C069","C09","C090","C091","C098","C099","C10","C100","C101","C102","C103",
              "C104","C108","C109","C12","C13","C130","C131","C132","C138","C139","C14","C140","C142","C148"],
    
    '白血病群組': ["C42","C420","C421","C91","C910","C9100","C9101","C9102","C911","C9110","C9111","C9112",
             "C913","C9130","C9131","C9132","C914","C9140","C9141","C9142","C915","C9150","C9151","C9152",
             "C916","C9160","C9161","C9162","C919","C9190","C9191","C9192","C91A","C91A0","C91A1","C91A2",
             "C91Z","C91Z0","C91Z1","C91Z2","C92","C920","C9200","C9201","C9202","C921","C9210","C9211",
             "C9212","C922","C9220","C9221","C9222","C923","C9230","C9231","C9232","C924","C9240","C9241",
             "C9242","C925","C9250","C9251","C9252","C926","C9260","C9261","C9262","C929","C9290","C9291",
             "C9292","C92A","C92A0","C92A1","C92A2","C92Z","C92Z0","C92Z1","C92Z2","C93","C930","C9300",
             "C9301","C9302","C931","C9310","C9311","C9312","C933","C9330","C9331","C9332","C939","C9390",
             "C9391","C9392","C93Z","C93Z0","C93Z1","C93Z2","C94","C940","C9400","C9401","C9402","C942",
             "C9420","C9421","C9422","C943","C9430","C9431","C9432","C944","C9440","C9441","C9442","C946",
             "C948","C9480","C9481","C9482","C95","C950","C9500","C9501","C9502","C951","C9510","C9511",
             "C9512","C959","C9590","C9591","C9592"],
    
    '肝外膽管癌群組': ["C24","C240","C241","C248","C249"],
    
    '肝癌群組': ["C22","C220","C221","C222","C223","C224","C227","C228","C229"],
    
    '乳癌群組': ["C50","C500","C5001","C50011","C50012","C50019","C5002","C50021","C50022","C50029","C501",
             "C5011","C50111","C50112","C50119","C5012","C50121","C50122","C50129","C502","C5021","C50211",
             "C50212","C50219","C5022","C50221","C50222","C50229","C503","C5031","C50311","C50312","C50319",
             "C5032","C50321","C50322","C50329","C504","C5041","C50411","C50412","C50419","C5042","C50421",
             "C50422","C50429","C505","C5051","C50511","C50512","C50519","C5052","C50521","C50522","C50529",
             "C506","C5061","C50611","C50612","C50619","C5062","C50621","C50622","C50629","C508","C5081",
             "C50811","C50812","C50819","C5082","C50821","C50822","C50829","C509","C5091","C50911","C50912",
             "C50919","C5092","C50921","C50922","C50929"],
    
    '肺癌群組': ["C33","C34","C340","C3400","C3401","C3402","C341","C3410","C3411","C3412","C342","C343","C3430",
             "C3431","C3432","C348","C3480","C3481","C3482","C349","C3490","C3491","C3492"],
    
    '胃癌群組': ["C16","C160","C161","C162","C163","C164","C165","C166","C168","C169"],
    
    '食道癌群組': ["C15","C153","C154","C155","C158","C159"],
    
    '胰臟癌群組': ["C25","C250","C251","C252","C253","C254","C257","C258","C259"],
    
    '腸癌群組': ["C17","C170","C171","C172","C173","C178","C179","C18","C180","C181","C182","C183","C184",
             "C185","C186","C187","C188","C189","C19","C20","C21","C210","C211","C212","C218"],
    
    '膽囊癌群組': ["C23","for_tuple_fill"]

}

def get_unique_ids(table_name, group_name, disease_codes):
    id_column = None
    other_columns = []

    if table_name == 'CRLF':
        id_column = 'id'
        other_columns = ['site']
    elif table_name == 'TOTFAE':
        id_column = 'd3'
        other_columns = ['d19', 'd20', 'd21', 'd22', 'd23']
    elif table_name == 'TOTFBE':
        id_column = 'd3'
        other_columns = ['d25', 'd26', 'd27', 'd28', 'd29']

    # 構建 SQL 查詢
    query = "SELECT DISTINCT {} FROM {} WHERE {}".format(id_column,table_name,' OR '.join([f'{col} LIKE \'%{code}%\'' for col in other_columns for code in disease_codes]))
    print(query)
    # 使用 pd.read_sql_query 讀取結果
    result = pd.read_sql_query(query, conn)
    
    return result[id_column]

# 初始化結果 DataFrame
result_df = pd.DataFrame(columns=['Group_name', 'CRLF_unique_id', 'TOTFAE_unique_id', 'TOTFBE__unique_id', 'MIX_unique_count'])

# 查找結果
for group_name, disease_codes in group_disease_mapping.items():
    CRLF_unique_id = get_unique_ids('CRLF', group_name, disease_codes)
    TOTFAE_unique_id = get_unique_ids('TOTFAE', group_name, disease_codes)
    TOTFBE__unique_id = get_unique_ids('TOTFBE', group_name, disease_codes)
    MIX_unique_count = pd.concat([CRLF_unique_id, TOTFAE_unique_id, TOTFBE__unique_id])
    
    # 將結果添加到結果 DataFrame
    result_df = result_df.append({
        'Group_name': group_name,
        'CRLF_unique_id': len(CRLF_unique_id),
        'TOTFAE_unique_id': len(TOTFAE_unique_id),
        'TOTFBE__unique_id': len(TOTFBE__unique_id),
        'MIX_unique_count': MIX_unique_count.nunique()
    }, ignore_index=True)

# 顯示結果
conn.close()
result_df
# Out:
# SELECT DISTINCT id FROM CRLF WHERE site LIKE '%C00%' OR site LIKE '%C000%' OR site LIKE '%C001%' OR site LIKE '%C002%' OR site LIKE '%C003%' OR site LIKE '%C004%' OR site LIKE '%C005%' OR site LIKE '%C006%' OR site LIKE '%C008%' OR site LIKE '%C009%' OR site LIKE '%C01%' OR site LIKE '%C02%' OR site LIKE '%C020%' OR site LIKE '%C021%' OR site LIKE '%C022%' OR site LIKE '%C023%' OR site LIKE '%C024%' OR site LIKE '%C028%' OR site LIKE '%C029%' OR site LIKE '%C03%' OR site LIKE '%C030%' OR site LIKE '%C031%' OR site LIKE '%C039%' OR site LIKE '%C04%' OR site LIKE '%C040%' OR site LIKE '%C041%' OR site LIKE '%C048%' OR site LIKE '%C049%' OR site LIKE '%C05%' OR site LIKE '%C050%' OR site LIKE '%C051%' OR site LIKE '%C052%' OR site LIKE '%C058%' OR site LIKE '%C059%' OR site LIKE '%C06%' OR site LIKE '%C060%' OR site LIKE '%C061%' OR site LIKE '%C062%' OR site LIKE '%C068%' OR site LIKE '%C0680%' OR site LIKE '%C0689%' OR site LIKE '%C069%' OR site LIKE '%C09%' OR site LIKE '%C090%' OR site LIKE '%C091%' OR site LIKE '%C098%' OR site LIKE '%C099%' OR site LIKE '%C10%' OR site LIKE '%C100%' OR site LIKE '%C101%' OR site LIKE '%C102%' OR site LIKE '%C103%' OR site LIKE '%C104%' OR site LIKE '%C108%' OR site LIKE '%C109%' OR site LIKE '%C12%' OR site LIKE '%C13%' OR site LIKE '%C130%' OR site LIKE '%C131%' OR site LIKE '%C132%' OR site LIKE '%C138%' OR site LIKE '%C139%' OR site LIKE '%C14%' OR site LIKE '%C140%' OR site LIKE '%C142%' OR site LIKE '%C148%'
# SELECT DISTINCT d3 FROM TOTFAE WHERE d19 LIKE '%C00%' OR d19 LIKE '%C000%' OR d19 LIKE '%C001%' OR d19 LIKE '%C002%' OR d19 LIKE '%C003%' OR d19 LIKE '%C004%' OR d19 LIKE '%C005%' OR d19 LIKE '%C006%' OR d19 LIKE '%C008%' OR d19 LIKE '%C009%' OR d19 LIKE '%C01%' OR d19 LIKE '%C02%' OR d19 LIKE '%C020%' OR d19 LIKE '%C021%' OR d19 LIKE '%C022%' OR d19 LIKE '%C023%' OR d19 LIKE '%C024%' OR d19 LIKE '%C028%' OR d19 LIKE '%C029%' OR d19 LIKE '%C03%' OR d19 LIKE '%C030%' OR d19 LIKE '%C031%' OR d19 LIKE '%C039%' OR d19 LIKE '%C04%' OR d19 LIKE '%C040%' OR d19 LIKE '%C041%' OR d19 LIKE '%C048%' OR d19 LIKE '%C049%' OR d19 LIKE '%C05%' OR d19 LIKE '%C050%' OR d19 LIKE '%C051%' OR d19 LIKE '%C052%' OR d19 LIKE '%C058%' OR d19 LIKE '%C059%' OR d19 LIKE '%C06%' OR d19 LIKE '%C060%' OR d19 LIKE '%C061%' OR d19 LIKE '%C062%' OR d19 LIKE '%C068%' OR d19 LIKE '%C0680%' OR d19 LIKE '%C0689%' OR d19 LIKE '%C069%' OR d19 LIKE '%C09%' OR d19 LIKE '%C090%' OR d19 LIKE '%C091%' OR d19 LIKE '%C098%' OR d19 LIKE '%C099%' OR d19 LIKE '%C10%' OR d19 LIKE '%C100%' OR d19 LIKE '%C101%' OR d19 LIKE '%C102%' OR d19 LIKE '%C103%' OR d19 LIKE '%C104%' OR d19 LIKE '%C108%' OR d19 LIKE '%C109%' OR d19 LIKE '%C12%' OR d19 LIKE '%C13%' OR d19 LIKE '%C130%' OR d19 LIKE '%C131%' OR d19 LIKE '%C132%' OR d19 LIKE '%C138%' OR d19 LIKE '%C139%' OR d19 LIKE '%C14%' OR d19 LIKE '%C140%' OR d19 LIKE '%C142%' OR d19 LIKE '%C148%' OR d20 LIKE '%C00%' OR d20 LIKE '%C000%' OR d20 LIKE '%C001%' OR d20 LIKE '%C002%' OR d20 LIKE '%C003%' OR d20 LIKE '%C004%' OR d20 LIKE '%C005%' OR d20 LIKE '%C006%' OR d20 LIKE '%C008%' OR d20 LIKE '%C009%' OR d20 LIKE '%C01%' OR d20 LIKE '%C02%' OR d20 LIKE '%C020%' OR d20 LIKE '%C021%' OR d20 LIKE '%C022%' OR d20 LIKE '%C023%' OR d20 LIKE '%C024%' OR d20 LIKE '%C028%' OR d20 LIKE '%C029%' OR d20 LIKE '%C03%' OR d20 LIKE '%C030%' OR d20 LIKE '%C031%' OR d20 LIKE '%C039%' OR d20 LIKE '%C04%' OR d20 LIKE '%C040%' OR d20 LIKE '%C041%' OR d20 LIKE '%C048%' OR d20 LIKE '%C049%' OR d20 LIKE '%C05%' OR d20 LIKE '%C050%' OR d20 LIKE '%C051%' OR d20 LIKE '%C052%' OR d20 LIKE '%C058%' OR d20 LIKE '%C059%' OR d20 LIKE '%C06%' OR d20 LIKE '%C060%' OR d20 LIKE '%C061%' OR d20 LIKE '%C062%' OR d20 LIKE '%C068%' OR d20 LIKE '%C0680%' OR d20 LIKE '%C0689%' OR d20 LIKE '%C069%' OR d20 LIKE '%C09%' OR d20 LIKE '%C090%' OR d20 LIKE '%C091%' OR d20 LIKE '%C098%' OR d20 LIKE '%C099%' OR d20 LIKE '%C10%' OR d20 LIKE '%C100%' OR d20 LIKE '%C101%' OR d20 LIKE '%C102%' OR d20 LIKE '%C103%' OR d20 LIKE '%C104%' OR d20 LIKE '%C108%' OR d20 LIKE '%C109%' OR d20 LIKE '%C12%' OR d20 LIKE '%C13%' OR d20 LIKE '%C130%' OR d20 LIKE '%C131%' OR d20 LIKE '%C132%' OR d20 LIKE '%C138%' OR d20 LIKE '%C139%' OR d20 LIKE '%C14%' OR d20 LIKE '%C140%' OR d20 LIKE '%C142%' OR d20 LIKE '%C148%' OR d21 LIKE '%C00%' OR d21 LIKE '%C000%' OR d21 LIKE '%C001%' OR d21 LIKE '%C002%' OR d21 LIKE '%C003%' OR d21 LIKE '%C004%' OR d21 LIKE '%C005%' OR d21 LIKE '%C006%' OR d21 LIKE '%C008%' OR d21 LIKE '%C009%' OR d21 LIKE '%C01%' OR d21 LIKE '%C02%' OR d21 LIKE '%C020%' OR d21 LIKE '%C021%' OR d21 LIKE '%C022%' OR d21 LIKE '%C023%' OR d21 LIKE '%C024%' OR d21 LIKE '%C028%' OR d21 LIKE '%C029%' OR d21 LIKE '%C03%' OR d21 LIKE '%C030%' OR d21 LIKE '%C031%' OR d21 LIKE '%C039%' OR d21 LIKE '%C04%' OR d21 LIKE '%C040%' OR d21 LIKE '%C041%' OR d21 LIKE '%C048%' OR d21 LIKE '%C049%' OR d21 LIKE '%C05%' OR d21 LIKE '%C050%' OR d21 LIKE '%C051%' OR d21 LIKE '%C052%' OR d21 LIKE '%C058%' OR d21 LIKE '%C059%' OR d21 LIKE '%C06%' OR d21 LIKE '%C060%' OR d21 LIKE '%C061%' OR d21 LIKE '%C062%' OR d21 LIKE '%C068%' OR d21 LIKE '%C0680%' OR d21 LIKE '%C0689%' OR d21 LIKE '%C069%' OR d21 LIKE '%C09%' OR d21 LIKE '%C090%' OR d21 LIKE '%C091%' OR d21 LIKE '%C098%' OR d21 LIKE '%C099%' OR d21 LIKE '%C10%' OR d21 LIKE '%C100%' OR d21 LIKE '%C101%' OR d21 LIKE '%C102%' OR d21 LIKE '%C103%' OR d21 LIKE '%C104%' OR d21 LIKE '%C108%' OR d21 LIKE '%C109%' OR d21 LIKE '%C12%' OR d21 LIKE '%C13%' OR d21 LIKE '%C130%' OR d2 ...
# SELECT DISTINCT d3 FROM TOTFBE WHERE d25 LIKE '%C00%' OR d25 LIKE '%C000%' OR d25 LIKE '%C001%' OR d25 LIKE '%C002%' OR d25 LIKE '%C003%' OR d25 LIKE '%C004%' OR d25 LIKE '%C005%' OR d25 LIKE '%C006%' OR d25 LIKE '%C008%' OR d25 LIKE '%C009%' OR d25 LIKE '%C01%' OR d25 LIKE '%C02%' OR d25 LIKE '%C020%' OR d25 LIKE '%C021%' OR d25 LIKE '%C022%' OR d25 LIKE '%C023%' OR d25 LIKE '%C024%' OR d25 LIKE '%C028%' OR d25 LIKE '%C029%' OR d25 LIKE '%C03%' OR d25 LIKE '%C030%' OR d25 LIKE '%C031%' OR d25 LIKE '%C039%' OR d25 LIKE '%C04%' OR d25 LIKE '%C040%' OR d25 LIKE '%C041%' OR d25 LIKE '%C048%' OR d25 LIKE '%C049%' OR d25 LIKE '%C05%' OR d25 LIKE '%C050%' OR d25 LIKE '%C051%' OR d25 LIKE '%C052%' OR d25 LIKE '%C058%' OR d25 LIKE '%C059%' OR d25 LIKE '%C06%' OR d25 LIKE '%C060%' OR d25 LIKE '%C061%' OR d25 LIKE '%C062%' OR d25 LIKE '%C068%' OR d25 LIKE '%C0680%' OR d25 LIKE '%C0689%' OR d25 LIKE '%C069%' OR d25 LIKE '%C09%' OR d25 LIKE '%C090%' OR d25 LIKE '%C091%' OR d25 LIKE '%C098%' OR d25 LIKE '%C099%' OR d25 LIKE '%C10%' OR d25 LIKE '%C100%' OR d25 LIKE '%C101%' OR d25 LIKE '%C102%' OR d25 LIKE '%C103%' OR d25 LIKE '%C104%' OR d25 LIKE '%C108%' OR d25 LIKE '%C109%' OR d25 LIKE '%C12%' OR d25 LIKE '%C13%' OR d25 LIKE '%C130%' OR d25 LIKE '%C131%' OR d25 LIKE '%C132%' OR d25 LIKE '%C138%' OR d25 LIKE '%C139%' OR d25 LIKE '%C14%' OR d25 LIKE '%C140%' OR d25 LIKE '%C142%' OR d25 LIKE '%C148%' OR d26 LIKE '%C00%' OR d26 LIKE '%C000%' OR d26 LIKE '%C001%' OR d26 LIKE '%C002%' OR d26 LIKE '%C003%' OR d26 LIKE '%C004%' OR d26 LIKE '%C005%' OR d26 LIKE '%C006%' OR d26 LIKE '%C008%' OR d26 LIKE '%C009%' OR d26 LIKE '%C01%' OR d26 LIKE '%C02%' OR d26 LIKE '%C020%' OR d26 LIKE '%C021%' OR d26 LIKE '%C022%' OR d26 LIKE '%C023%' OR d26 LIKE '%C024%' OR d26 LIKE '%C028%' OR d26 LIKE '%C029%' OR d26 LIKE '%C03%' OR d26 LIKE '%C030%' OR d26 LIKE '%C031%' OR d26 LIKE '%C039%' OR d26 LIKE '%C04%' OR d26 LIKE '%C040%' OR d26 LIKE '%C041%' OR d26 LIKE '%C048%' OR d26 LIKE '%C049%' OR d26 LIKE '%C05%' OR d26 LIKE '%C050%' OR d26 LIKE '%C051%' OR d26 LIKE '%C052%' OR d26 LIKE '%C058%' OR d26 LIKE '%C059%' OR d26 LIKE '%C06%' OR d26 LIKE '%C060%' OR d26 LIKE '%C061%' OR d26 LIKE '%C062%' OR d26 LIKE '%C068%' OR d26 LIKE '%C0680%' OR d26 LIKE '%C0689%' OR d26 LIKE '%C069%' OR d26 LIKE '%C09%' OR d26 LIKE '%C090%' OR d26 LIKE '%C091%' OR d26 LIKE '%C098%' OR d26 LIKE '%C099%' OR d26 LIKE '%C10%' OR d26 LIKE '%C100%' OR d26 LIKE '%C101%' OR d26 LIKE '%C102%' OR d26 LIKE '%C103%' OR d26 LIKE '%C104%' OR d26 LIKE '%C108%' OR d26 LIKE '%C109%' OR d26 LIKE '%C12%' OR d26 LIKE '%C13%' OR d26 LIKE '%C130%' OR d26 LIKE '%C131%' OR d26 LIKE '%C132%' OR d26 LIKE '%C138%' OR d26 LIKE '%C139%' OR d26 LIKE '%C14%' OR d26 LIKE '%C140%' OR d26 LIKE '%C142%' OR d26 LIKE '%C148%' OR d27 LIKE '%C00%' OR d27 LIKE '%C000%' OR d27 LIKE '%C001%' OR d27 LIKE '%C002%' OR d27 LIKE '%C003%' OR d27 LIKE '%C004%' OR d27 LIKE '%C005%' OR d27 LIKE '%C006%' OR d27 LIKE '%C008%' OR d27 LIKE '%C009%' OR d27 LIKE '%C01%' OR d27 LIKE '%C02%' OR d27 LIKE '%C020%' OR d27 LIKE '%C021%' OR d27 LIKE '%C022%' OR d27 LIKE '%C023%' OR d27 LIKE '%C024%' OR d27 LIKE '%C028%' OR d27 LIKE '%C029%' OR d27 LIKE '%C03%' OR d27 LIKE '%C030%' OR d27 LIKE '%C031%' OR d27 LIKE '%C039%' OR d27 LIKE '%C04%' OR d27 LIKE '%C040%' OR d27 LIKE '%C041%' OR d27 LIKE '%C048%' OR d27 LIKE '%C049%' OR d27 LIKE '%C05%' OR d27 LIKE '%C050%' OR d27 LIKE '%C051%' OR d27 LIKE '%C052%' OR d27 LIKE '%C058%' OR d27 LIKE '%C059%' OR d27 LIKE '%C06%' OR d27 LIKE '%C060%' OR d27 LIKE '%C061%' OR d27 LIKE '%C062%' OR d27 LIKE '%C068%' OR d27 LIKE '%C0680%' OR d27 LIKE '%C0689%' OR d27 LIKE '%C069%' OR d27 LIKE '%C09%' OR d27 LIKE '%C090%' OR d27 LIKE '%C091%' OR d27 LIKE '%C098%' OR d27 LIKE '%C099%' OR d27 LIKE '%C10%' OR d27 LIKE '%C100%' OR d27 LIKE '%C101%' OR d27 LIKE '%C102%' OR d27 LIKE '%C103%' OR d27 LIKE '%C104%' OR d27 LIKE '%C108%' OR d27 LIKE '%C109%' OR d27 LIKE '%C12%' OR d27 LIKE '%C13%' OR d27 LIKE '%C130%' OR d2 ...
# SELECT DISTINCT id FROM CRLF WHERE site LIKE '%C42%' OR site LIKE '%C420%' OR site LIKE '%C421%' OR site LIKE '%C91%' OR site LIKE '%C910%' OR site LIKE '%C9100%' OR site LIKE '%C9101%' OR site LIKE '%C9102%' OR site LIKE '%C911%' OR site LIKE '%C9110%' OR site LIKE '%C9111%' OR site LIKE '%C9112%' OR site LIKE '%C913%' OR site LIKE '%C9130%' OR site LIKE '%C9131%' OR site LIKE '%C9132%' OR site LIKE '%C914%' OR site LIKE '%C9140%' OR site LIKE '%C9141%' OR site LIKE '%C9142%' OR site LIKE '%C915%' OR site LIKE '%C9150%' OR site LIKE '%C9151%' OR site LIKE '%C9152%' OR site LIKE '%C916%' OR site LIKE '%C9160%' OR site LIKE '%C9161%' OR site LIKE '%C9162%' OR site LIKE '%C919%' OR site LIKE '%C9190%' OR site LIKE '%C9191%' OR site LIKE '%C9192%' OR site LIKE '%C91A%' OR site LIKE '%C91A0%' OR site LIKE '%C91A1%' OR site LIKE '%C91A2%' OR site LIKE '%C91Z%' OR site LIKE '%C91Z0%' OR site LIKE '%C91Z1%' OR site LIKE '%C91Z2%' OR site LIKE '%C92%' OR site LIKE '%C920%' OR site LIKE '%C9200%' OR site LIKE '%C9201%' OR site LIKE '%C9202%' OR site LIKE '%C921%' OR site LIKE '%C9210%' OR site LIKE '%C9211%' OR site LIKE '%C9212%' OR site LIKE '%C922%' OR site LIKE '%C9220%' OR site LIKE '%C9221%' OR site LIKE '%C9222%' OR site LIKE '%C923%' OR site LIKE '%C9230%' OR site LIKE '%C9231%' OR site LIKE '%C9232%' OR site LIKE '%C924%' OR site LIKE '%C9240%' OR site LIKE '%C9241%' OR site LIKE '%C9242%' OR site LIKE '%C925%' OR site LIKE '%C9250%' OR site LIKE '%C9251%' OR site LIKE '%C9252%' OR site LIKE '%C926%' OR site LIKE '%C9260%' OR site LIKE '%C9261%' OR site LIKE '%C9262%' OR site LIKE '%C929%' OR site LIKE '%C9290%' OR site LIKE '%C9291%' OR site LIKE '%C9292%' OR site LIKE '%C92A%' OR site LIKE '%C92A0%' OR site LIKE '%C92A1%' OR site LIKE '%C92A2%' OR site LIKE '%C92Z%' OR site LIKE '%C92Z0%' OR site LIKE '%C92Z1%' OR site LIKE '%C92Z2%' OR site LIKE '%C93%' OR site LIKE '%C930%' OR site LIKE '%C9300%' OR site LIKE '%C9301%' OR site LIKE '%C9302%' OR site LIKE '%C931%' OR site LIKE '%C9310%' OR site LIKE '%C9311%' OR site LIKE '%C9312%' OR site LIKE '%C933%' OR site LIKE '%C9330%' OR site LIKE '%C9331%' OR site LIKE '%C9332%' OR site LIKE '%C939%' OR site LIKE '%C9390%' OR site LIKE '%C9391%' OR site LIKE '%C9392%' OR site LIKE '%C93Z%' OR site LIKE '%C93Z0%' OR site LIKE '%C93Z1%' OR site LIKE '%C93Z2%' OR site LIKE '%C94%' OR site LIKE '%C940%' OR site LIKE '%C9400%' OR site LIKE '%C9401%' OR site LIKE '%C9402%' OR site LIKE '%C942%' OR site LIKE '%C9420%' OR site LIKE '%C9421%' OR site LIKE '%C9422%' OR site LIKE '%C943%' OR site LIKE '%C9430%' OR site LIKE '%C9431%' OR site LIKE '%C9432%' OR site LIKE '%C944%' OR site LIKE '%C9440%' OR site LIKE '%C9441%' OR site LIKE '%C9442%' OR site LIKE '%C946%' OR site LIKE '%C948%' OR site LIKE '%C9480%' OR site LIKE '%C9481%' OR site LIKE '%C9482%' OR site LIKE '%C95%' OR site LIKE '%C950%' OR site LIKE '%C9500%' OR site LIKE '%C9501%' OR site LIKE '%C9502%' OR site LIKE '%C951%' OR site LIKE '%C9510%' OR site LIKE '%C9511%' OR site LIKE '%C9512%' OR site LIKE '%C959%' OR site LIKE '%C9590%' OR site LIKE '%C9591%' OR site LIKE '%C9592%'
# SELECT DISTINCT d3 FROM TOTFAE WHERE d19 LIKE '%C42%' OR d19 LIKE '%C420%' OR d19 LIKE '%C421%' OR d19 LIKE '%C91%' OR d19 LIKE '%C910%' OR d19 LIKE '%C9100%' OR d19 LIKE '%C9101%' OR d19 LIKE '%C9102%' OR d19 LIKE '%C911%' OR d19 LIKE '%C9110%' OR d19 LIKE '%C9111%' OR d19 LIKE '%C9112%' OR d19 LIKE '%C913%' OR d19 LIKE '%C9130%' OR d19 LIKE '%C9131%' OR d19 LIKE '%C9132%' OR d19 LIKE '%C914%' OR d19 LIKE '%C9140%' OR d19 LIKE '%C9141%' OR d19 LIKE '%C9142%' OR d19 LIKE '%C915%' OR d19 LIKE '%C9150%' OR d19 LIKE '%C9151%' OR d19 LIKE '%C9152%' OR d19 LIKE '%C916%' OR d19 LIKE '%C9160%' OR d19 LIKE '%C9161%' OR d19 LIKE '%C9162%' OR d19 LIKE '%C919%' OR d19 LIKE '%C9190%' OR d19 LIKE '%C9191%' OR d19 LIKE '%C9192%' OR d19 LIKE '%C91A%' OR d19 LIKE '%C91A0%' OR d19 LIKE '%C91A1%' OR d19 LIKE '%C91A2%' OR d19 LIKE '%C91Z%' OR d19 LIKE '%C91Z0%' OR d19 LIKE '%C91Z1%' OR d19 LIKE '%C91Z2%' OR d19 LIKE '%C92%' OR d19 LIKE '%C920%' OR d19 LIKE '%C9200%' OR d19 LIKE '%C9201%' OR d19 LIKE '%C9202%' OR d19 LIKE '%C921%' OR d19 LIKE '%C9210%' OR d19 LIKE '%C9211%' OR d19 LIKE '%C9212%' OR d19 LIKE '%C922%' OR d19 LIKE '%C9220%' OR d19 LIKE '%C9221%' OR d19 LIKE '%C9222%' OR d19 LIKE '%C923%' OR d19 LIKE '%C9230%' OR d19 LIKE '%C9231%' OR d19 LIKE '%C9232%' OR d19 LIKE '%C924%' OR d19 LIKE '%C9240%' OR d19 LIKE '%C9241%' OR d19 LIKE '%C9242%' OR d19 LIKE '%C925%' OR d19 LIKE '%C9250%' OR d19 LIKE '%C9251%' OR d19 LIKE '%C9252%' OR d19 LIKE '%C926%' OR d19 LIKE '%C9260%' OR d19 LIKE '%C9261%' OR d19 LIKE '%C9262%' OR d19 LIKE '%C929%' OR d19 LIKE '%C9290%' OR d19 LIKE '%C9291%' OR d19 LIKE '%C9292%' OR d19 LIKE '%C92A%' OR d19 LIKE '%C92A0%' OR d19 LIKE '%C92A1%' OR d19 LIKE '%C92A2%' OR d19 LIKE '%C92Z%' OR d19 LIKE '%C92Z0%' OR d19 LIKE '%C92Z1%' OR d19 LIKE '%C92Z2%' OR d19 LIKE '%C93%' OR d19 LIKE '%C930%' OR d19 LIKE '%C9300%' OR d19 LIKE '%C9301%' OR d19 LIKE '%C9302%' OR d19 LIKE '%C931%' OR d19 LIKE '%C9310%' OR d19 LIKE '%C9311%' OR d19 LIKE '%C9312%' OR d19 LIKE '%C933%' OR d19 LIKE '%C9330%' OR d19 LIKE '%C9331%' OR d19 LIKE '%C9332%' OR d19 LIKE '%C939%' OR d19 LIKE '%C9390%' OR d19 LIKE '%C9391%' OR d19 LIKE '%C9392%' OR d19 LIKE '%C93Z%' OR d19 LIKE '%C93Z0%' OR d19 LIKE '%C93Z1%' OR d19 LIKE '%C93Z2%' OR d19 LIKE '%C94%' OR d19 LIKE '%C940%' OR d19 LIKE '%C9400%' OR d19 LIKE '%C9401%' OR d19 LIKE '%C9402%' OR d19 LIKE '%C942%' OR d19 LIKE '%C9420%' OR d19 LIKE '%C9421%' OR d19 LIKE '%C9422%' OR d19 LIKE '%C943%' OR d19 LIKE '%C9430%' OR d19 LIKE '%C9431%' OR d19 LIKE '%C9432%' OR d19 LIKE '%C944%' OR d19 LIKE '%C9440%' OR d19 LIKE '%C9441%' OR d19 LIKE '%C9442%' OR d19 LIKE '%C946%' OR d19 LIKE '%C948%' OR d19 LIKE '%C9480%' OR d19 LIKE '%C9481%' OR d19 LIKE '%C9482%' OR d19 LIKE '%C95%' OR d19 LIKE '%C950%' OR d19 LIKE '%C9500%' OR d19 LIKE '%C9501%' OR d19 LIKE '%C9502%' OR d19 LIKE '%C951%' OR d19 LIKE '%C9510%' OR d19 LIKE '%C9511%' OR d19 LIKE '%C9512%' OR d19 LIKE '%C959%' OR d19 LIKE '%C9590%' OR d19 LIKE '%C9591%' OR d19 LIKE '%C9592%' OR d20 LIKE '%C42%' OR d20 LIKE '%C420%' OR d20 LIKE '%C421%' OR d20 LIKE '%C91%' OR d20 LIKE '%C910%' OR d20 LIKE '%C9100%' OR d20 LIKE '%C9101%' OR d20 LIKE '%C9102%' OR d20 LIKE '%C911%' OR d20 LIKE '%C9110%' OR d20 LIKE '%C9111%' OR d20 LIKE '%C9112%' OR d20 LIKE '%C913%' OR d20 LIKE '%C9130%' OR d20 LIKE '%C9131%' OR d20 LIKE '%C9132%' OR d20 LIKE '%C914%' OR d20 LIKE '%C9140%' OR d20 LIKE '%C9141%' OR d20 LIKE '%C9142%' OR d20 LIKE '%C915%' OR d20 LIKE '%C9150%' OR d20 LIKE '%C9151%' OR d20 LIKE '%C9152%' OR d20 LIKE '%C916%' OR d20 LIKE '%C9160%' OR d20 LIKE '%C9161%' OR d20 LIKE '%C9162%' OR d20 LIKE '%C919%' OR d20 LIKE '%C9190%' OR d20 LIKE '%C9191%' OR d20 LIKE '%C9192%' OR d20 LIKE '%C91A%' OR d20 LIKE '%C91A0%' OR d20 LIKE '%C91A1%' OR d20 LIKE '%C91A2%' OR d20 LIKE '%C91Z%' OR d20 LIKE '%C91Z0%' OR d20 LIKE '%C91Z1%' OR d20 LIKE '%C91Z2%' OR d20 LIKE '%C92%' OR d20 LIKE '%C920%' OR d20 LIKE '%C9200%' OR d20 LIKE '%C9201%' OR d20 LIKE '%C9202%' OR d20 LIKE '%C921%' OR d20 ...
# SELECT DISTINCT d3 FROM TOTFBE WHERE d25 LIKE '%C42%' OR d25 LIKE '%C420%' OR d25 LIKE '%C421%' OR d25 LIKE '%C91%' OR d25 LIKE '%C910%' OR d25 LIKE '%C9100%' OR d25 LIKE '%C9101%' OR d25 LIKE '%C9102%' OR d25 LIKE '%C911%' OR d25 LIKE '%C9110%' OR d25 LIKE '%C9111%' OR d25 LIKE '%C9112%' OR d25 LIKE '%C913%' OR d25 LIKE '%C9130%' OR d25 LIKE '%C9131%' OR d25 LIKE '%C9132%' OR d25 LIKE '%C914%' OR d25 LIKE '%C9140%' OR d25 LIKE '%C9141%' OR d25 LIKE '%C9142%' OR d25 LIKE '%C915%' OR d25 LIKE '%C9150%' OR d25 LIKE '%C9151%' OR d25 LIKE '%C9152%' OR d25 LIKE '%C916%' OR d25 LIKE '%C9160%' OR d25 LIKE '%C9161%' OR d25 LIKE '%C9162%' OR d25 LIKE '%C919%' OR d25 LIKE '%C9190%' OR d25 LIKE '%C9191%' OR d25 LIKE '%C9192%' OR d25 LIKE '%C91A%' OR d25 LIKE '%C91A0%' OR d25 LIKE '%C91A1%' OR d25 LIKE '%C91A2%' OR d25 LIKE '%C91Z%' OR d25 LIKE '%C91Z0%' OR d25 LIKE '%C91Z1%' OR d25 LIKE '%C91Z2%' OR d25 LIKE '%C92%' OR d25 LIKE '%C920%' OR d25 LIKE '%C9200%' OR d25 LIKE '%C9201%' OR d25 LIKE '%C9202%' OR d25 LIKE '%C921%' OR d25 LIKE '%C9210%' OR d25 LIKE '%C9211%' OR d25 LIKE '%C9212%' OR d25 LIKE '%C922%' OR d25 LIKE '%C9220%' OR d25 LIKE '%C9221%' OR d25 LIKE '%C9222%' OR d25 LIKE '%C923%' OR d25 LIKE '%C9230%' OR d25 LIKE '%C9231%' OR d25 LIKE '%C9232%' OR d25 LIKE '%C924%' OR d25 LIKE '%C9240%' OR d25 LIKE '%C9241%' OR d25 LIKE '%C9242%' OR d25 LIKE '%C925%' OR d25 LIKE '%C9250%' OR d25 LIKE '%C9251%' OR d25 LIKE '%C9252%' OR d25 LIKE '%C926%' OR d25 LIKE '%C9260%' OR d25 LIKE '%C9261%' OR d25 LIKE '%C9262%' OR d25 LIKE '%C929%' OR d25 LIKE '%C9290%' OR d25 LIKE '%C9291%' OR d25 LIKE '%C9292%' OR d25 LIKE '%C92A%' OR d25 LIKE '%C92A0%' OR d25 LIKE '%C92A1%' OR d25 LIKE '%C92A2%' OR d25 LIKE '%C92Z%' OR d25 LIKE '%C92Z0%' OR d25 LIKE '%C92Z1%' OR d25 LIKE '%C92Z2%' OR d25 LIKE '%C93%' OR d25 LIKE '%C930%' OR d25 LIKE '%C9300%' OR d25 LIKE '%C9301%' OR d25 LIKE '%C9302%' OR d25 LIKE '%C931%' OR d25 LIKE '%C9310%' OR d25 LIKE '%C9311%' OR d25 LIKE '%C9312%' OR d25 LIKE '%C933%' OR d25 LIKE '%C9330%' OR d25 LIKE '%C9331%' OR d25 LIKE '%C9332%' OR d25 LIKE '%C939%' OR d25 LIKE '%C9390%' OR d25 LIKE '%C9391%' OR d25 LIKE '%C9392%' OR d25 LIKE '%C93Z%' OR d25 LIKE '%C93Z0%' OR d25 LIKE '%C93Z1%' OR d25 LIKE '%C93Z2%' OR d25 LIKE '%C94%' OR d25 LIKE '%C940%' OR d25 LIKE '%C9400%' OR d25 LIKE '%C9401%' OR d25 LIKE '%C9402%' OR d25 LIKE '%C942%' OR d25 LIKE '%C9420%' OR d25 LIKE '%C9421%' OR d25 LIKE '%C9422%' OR d25 LIKE '%C943%' OR d25 LIKE '%C9430%' OR d25 LIKE '%C9431%' OR d25 LIKE '%C9432%' OR d25 LIKE '%C944%' OR d25 LIKE '%C9440%' OR d25 LIKE '%C9441%' OR d25 LIKE '%C9442%' OR d25 LIKE '%C946%' OR d25 LIKE '%C948%' OR d25 LIKE '%C9480%' OR d25 LIKE '%C9481%' OR d25 LIKE '%C9482%' OR d25 LIKE '%C95%' OR d25 LIKE '%C950%' OR d25 LIKE '%C9500%' OR d25 LIKE '%C9501%' OR d25 LIKE '%C9502%' OR d25 LIKE '%C951%' OR d25 LIKE '%C9510%' OR d25 LIKE '%C9511%' OR d25 LIKE '%C9512%' OR d25 LIKE '%C959%' OR d25 LIKE '%C9590%' OR d25 LIKE '%C9591%' OR d25 LIKE '%C9592%' OR d26 LIKE '%C42%' OR d26 LIKE '%C420%' OR d26 LIKE '%C421%' OR d26 LIKE '%C91%' OR d26 LIKE '%C910%' OR d26 LIKE '%C9100%' OR d26 LIKE '%C9101%' OR d26 LIKE '%C9102%' OR d26 LIKE '%C911%' OR d26 LIKE '%C9110%' OR d26 LIKE '%C9111%' OR d26 LIKE '%C9112%' OR d26 LIKE '%C913%' OR d26 LIKE '%C9130%' OR d26 LIKE '%C9131%' OR d26 LIKE '%C9132%' OR d26 LIKE '%C914%' OR d26 LIKE '%C9140%' OR d26 LIKE '%C9141%' OR d26 LIKE '%C9142%' OR d26 LIKE '%C915%' OR d26 LIKE '%C9150%' OR d26 LIKE '%C9151%' OR d26 LIKE '%C9152%' OR d26 LIKE '%C916%' OR d26 LIKE '%C9160%' OR d26 LIKE '%C9161%' OR d26 LIKE '%C9162%' OR d26 LIKE '%C919%' OR d26 LIKE '%C9190%' OR d26 LIKE '%C9191%' OR d26 LIKE '%C9192%' OR d26 LIKE '%C91A%' OR d26 LIKE '%C91A0%' OR d26 LIKE '%C91A1%' OR d26 LIKE '%C91A2%' OR d26 LIKE '%C91Z%' OR d26 LIKE '%C91Z0%' OR d26 LIKE '%C91Z1%' OR d26 LIKE '%C91Z2%' OR d26 LIKE '%C92%' OR d26 LIKE '%C920%' OR d26 LIKE '%C9200%' OR d26 LIKE '%C9201%' OR d26 LIKE '%C9202%' OR d26 LIKE '%C921%' OR d26 ...
# SELECT DISTINCT id FROM CRLF WHERE site LIKE '%C24%' OR site LIKE '%C240%' OR site LIKE '%C241%' OR site LIKE '%C248%' OR site LIKE '%C249%'
# SELECT DISTINCT d3 FROM TOTFAE WHERE d19 LIKE '%C24%' OR d19 LIKE '%C240%' OR d19 LIKE '%C241%' OR d19 LIKE '%C248%' OR d19 LIKE '%C249%' OR d20 LIKE '%C24%' OR d20 LIKE '%C240%' OR d20 LIKE '%C241%' OR d20 LIKE '%C248%' OR d20 LIKE '%C249%' OR d21 LIKE '%C24%' OR d21 LIKE '%C240%' OR d21 LIKE '%C241%' OR d21 LIKE '%C248%' OR d21 LIKE '%C249%' OR d22 LIKE '%C24%' OR d22 LIKE '%C240%' OR d22 LIKE '%C241%' OR d22 LIKE '%C248%' OR d22 LIKE '%C249%' OR d23 LIKE '%C24%' OR d23 LIKE '%C240%' OR d23 LIKE '%C241%' OR d23 LIKE '%C248%' OR d23 LIKE '%C249%'
# SELECT DISTINCT d3 FROM TOTFBE WHERE d25 LIKE '%C24%' OR d25 LIKE '%C240%' OR d25 LIKE '%C241%' OR d25 LIKE '%C248%' OR d25 LIKE '%C249%' OR d26 LIKE '%C24%' OR d26 LIKE '%C240%' OR d26 LIKE '%C241%' OR d26 LIKE '%C248%' OR d26 LIKE '%C249%' OR d27 LIKE '%C24%' OR d27 LIKE '%C240%' OR d27 LIKE '%C241%' OR d27 LIKE '%C248%' OR d27 LIKE '%C249%' OR d28 LIKE '%C24%' OR d28 LIKE '%C240%' OR d28 LIKE '%C241%' OR d28 LIKE '%C248%' OR d28 LIKE '%C249%' OR d29 LIKE '%C24%' OR d29 LIKE '%C240%' OR d29 LIKE '%C241%' OR d29 LIKE '%C248%' OR d29 LIKE '%C249%'
# SELECT DISTINCT id FROM CRLF WHERE site LIKE '%C22%' OR site LIKE '%C220%' OR site LIKE '%C221%' OR site LIKE '%C222%' OR site LIKE '%C223%' OR site LIKE '%C224%' OR site LIKE '%C227%' OR site LIKE '%C228%' OR site LIKE '%C229%'
# SELECT DISTINCT d3 FROM TOTFAE WHERE d19 LIKE '%C22%' OR d19 LIKE '%C220%' OR d19 LIKE '%C221%' OR d19 LIKE '%C222%' OR d19 LIKE '%C223%' OR d19 LIKE '%C224%' OR d19 LIKE '%C227%' OR d19 LIKE '%C228%' OR d19 LIKE '%C229%' OR d20 LIKE '%C22%' OR d20 LIKE '%C220%' OR d20 LIKE '%C221%' OR d20 LIKE '%C222%' OR d20 LIKE '%C223%' OR d20 LIKE '%C224%' OR d20 LIKE '%C227%' OR d20 LIKE '%C228%' OR d20 LIKE '%C229%' OR d21 LIKE '%C22%' OR d21 LIKE '%C220%' OR d21 LIKE '%C221%' OR d21 LIKE '%C222%' OR d21 LIKE '%C223%' OR d21 LIKE '%C224%' OR d21 LIKE '%C227%' OR d21 LIKE '%C228%' OR d21 LIKE '%C229%' OR d22 LIKE '%C22%' OR d22 LIKE '%C220%' OR d22 LIKE '%C221%' OR d22 LIKE '%C222%' OR d22 LIKE '%C223%' OR d22 LIKE '%C224%' OR d22 LIKE '%C227%' OR d22 LIKE '%C228%' OR d22 LIKE '%C229%' OR d23 LIKE '%C22%' OR d23 LIKE '%C220%' OR d23 LIKE '%C221%' OR d23 LIKE '%C222%' OR d23 LIKE '%C223%' OR d23 LIKE '%C224%' OR d23 LIKE '%C227%' OR d23 LIKE '%C228%' OR d23 LIKE '%C229%'
# SELECT DISTINCT d3 FROM TOTFBE WHERE d25 LIKE '%C22%' OR d25 LIKE '%C220%' OR d25 LIKE '%C221%' OR d25 LIKE '%C222%' OR d25 LIKE '%C223%' OR d25 LIKE '%C224%' OR d25 LIKE '%C227%' OR d25 LIKE '%C228%' OR d25 LIKE '%C229%' OR d26 LIKE '%C22%' OR d26 LIKE '%C220%' OR d26 LIKE '%C221%' OR d26 LIKE '%C222%' OR d26 LIKE '%C223%' OR d26 LIKE '%C224%' OR d26 LIKE '%C227%' OR d26 LIKE '%C228%' OR d26 LIKE '%C229%' OR d27 LIKE '%C22%' OR d27 LIKE '%C220%' OR d27 LIKE '%C221%' OR d27 LIKE '%C222%' OR d27 LIKE '%C223%' OR d27 LIKE '%C224%' OR d27 LIKE '%C227%' OR d27 LIKE '%C228%' OR d27 LIKE '%C229%' OR d28 LIKE '%C22%' OR d28 LIKE '%C220%' OR d28 LIKE '%C221%' OR d28 LIKE '%C222%' OR d28 LIKE '%C223%' OR d28 LIKE '%C224%' OR d28 LIKE '%C227%' OR d28 LIKE '%C228%' OR d28 LIKE '%C229%' OR d29 LIKE '%C22%' OR d29 LIKE '%C220%' OR d29 LIKE '%C221%' OR d29 LIKE '%C222%' OR d29 LIKE '%C223%' OR d29 LIKE '%C224%' OR d29 LIKE '%C227%' OR d29 LIKE '%C228%' OR d29 LIKE '%C229%'
# SELECT DISTINCT id FROM CRLF WHERE site LIKE '%C50%' OR site LIKE '%C500%' OR site LIKE '%C5001%' OR site LIKE '%C50011%' OR site LIKE '%C50012%' OR site LIKE '%C50019%' OR site LIKE '%C5002%' OR site LIKE '%C50021%' OR site LIKE '%C50022%' OR site LIKE '%C50029%' OR site LIKE '%C501%' OR site LIKE '%C5011%' OR site LIKE '%C50111%' OR site LIKE '%C50112%' OR site LIKE '%C50119%' OR site LIKE '%C5012%' OR site LIKE '%C50121%' OR site LIKE '%C50122%' OR site LIKE '%C50129%' OR site LIKE '%C502%' OR site LIKE '%C5021%' OR site LIKE '%C50211%' OR site LIKE '%C50212%' OR site LIKE '%C50219%' OR site LIKE '%C5022%' OR site LIKE '%C50221%' OR site LIKE '%C50222%' OR site LIKE '%C50229%' OR site LIKE '%C503%' OR site LIKE '%C5031%' OR site LIKE '%C50311%' OR site LIKE '%C50312%' OR site LIKE '%C50319%' OR site LIKE '%C5032%' OR site LIKE '%C50321%' OR site LIKE '%C50322%' OR site LIKE '%C50329%' OR site LIKE '%C504%' OR site LIKE '%C5041%' OR site LIKE '%C50411%' OR site LIKE '%C50412%' OR site LIKE '%C50419%' OR site LIKE '%C5042%' OR site LIKE '%C50421%' OR site LIKE '%C50422%' OR site LIKE '%C50429%' OR site LIKE '%C505%' OR site LIKE '%C5051%' OR site LIKE '%C50511%' OR site LIKE '%C50512%' OR site LIKE '%C50519%' OR site LIKE '%C5052%' OR site LIKE '%C50521%' OR site LIKE '%C50522%' OR site LIKE '%C50529%' OR site LIKE '%C506%' OR site LIKE '%C5061%' OR site LIKE '%C50611%' OR site LIKE '%C50612%' OR site LIKE '%C50619%' OR site LIKE '%C5062%' OR site LIKE '%C50621%' OR site LIKE '%C50622%' OR site LIKE '%C50629%' OR site LIKE '%C508%' OR site LIKE '%C5081%' OR site LIKE '%C50811%' OR site LIKE '%C50812%' OR site LIKE '%C50819%' OR site LIKE '%C5082%' OR site LIKE '%C50821%' OR site LIKE '%C50822%' OR site LIKE '%C50829%' OR site LIKE '%C509%' OR site LIKE '%C5091%' OR site LIKE '%C50911%' OR site LIKE '%C50912%' OR site LIKE '%C50919%' OR site LIKE '%C5092%' OR site LIKE '%C50921%' OR site LIKE '%C50922%' OR site LIKE '%C50929%'
# SELECT DISTINCT d3 FROM TOTFAE WHERE d19 LIKE '%C50%' OR d19 LIKE '%C500%' OR d19 LIKE '%C5001%' OR d19 LIKE '%C50011%' OR d19 LIKE '%C50012%' OR d19 LIKE '%C50019%' OR d19 LIKE '%C5002%' OR d19 LIKE '%C50021%' OR d19 LIKE '%C50022%' OR d19 LIKE '%C50029%' OR d19 LIKE '%C501%' OR d19 LIKE '%C5011%' OR d19 LIKE '%C50111%' OR d19 LIKE '%C50112%' OR d19 LIKE '%C50119%' OR d19 LIKE '%C5012%' OR d19 LIKE '%C50121%' OR d19 LIKE '%C50122%' OR d19 LIKE '%C50129%' OR d19 LIKE '%C502%' OR d19 LIKE '%C5021%' OR d19 LIKE '%C50211%' OR d19 LIKE '%C50212%' OR d19 LIKE '%C50219%' OR d19 LIKE '%C5022%' OR d19 LIKE '%C50221%' OR d19 LIKE '%C50222%' OR d19 LIKE '%C50229%' OR d19 LIKE '%C503%' OR d19 LIKE '%C5031%' OR d19 LIKE '%C50311%' OR d19 LIKE '%C50312%' OR d19 LIKE '%C50319%' OR d19 LIKE '%C5032%' OR d19 LIKE '%C50321%' OR d19 LIKE '%C50322%' OR d19 LIKE '%C50329%' OR d19 LIKE '%C504%' OR d19 LIKE '%C5041%' OR d19 LIKE '%C50411%' OR d19 LIKE '%C50412%' OR d19 LIKE '%C50419%' OR d19 LIKE '%C5042%' OR d19 LIKE '%C50421%' OR d19 LIKE '%C50422%' OR d19 LIKE '%C50429%' OR d19 LIKE '%C505%' OR d19 LIKE '%C5051%' OR d19 LIKE '%C50511%' OR d19 LIKE '%C50512%' OR d19 LIKE '%C50519%' OR d19 LIKE '%C5052%' OR d19 LIKE '%C50521%' OR d19 LIKE '%C50522%' OR d19 LIKE '%C50529%' OR d19 LIKE '%C506%' OR d19 LIKE '%C5061%' OR d19 LIKE '%C50611%' OR d19 LIKE '%C50612%' OR d19 LIKE '%C50619%' OR d19 LIKE '%C5062%' OR d19 LIKE '%C50621%' OR d19 LIKE '%C50622%' OR d19 LIKE '%C50629%' OR d19 LIKE '%C508%' OR d19 LIKE '%C5081%' OR d19 LIKE '%C50811%' OR d19 LIKE '%C50812%' OR d19 LIKE '%C50819%' OR d19 LIKE '%C5082%' OR d19 LIKE '%C50821%' OR d19 LIKE '%C50822%' OR d19 LIKE '%C50829%' OR d19 LIKE '%C509%' OR d19 LIKE '%C5091%' OR d19 LIKE '%C50911%' OR d19 LIKE '%C50912%' OR d19 LIKE '%C50919%' OR d19 LIKE '%C5092%' OR d19 LIKE '%C50921%' OR d19 LIKE '%C50922%' OR d19 LIKE '%C50929%' OR d20 LIKE '%C50%' OR d20 LIKE '%C500%' OR d20 LIKE '%C5001%' OR d20 LIKE '%C50011%' OR d20 LIKE '%C50012%' OR d20 LIKE '%C50019%' OR d20 LIKE '%C5002%' OR d20 LIKE '%C50021%' OR d20 LIKE '%C50022%' OR d20 LIKE '%C50029%' OR d20 LIKE '%C501%' OR d20 LIKE '%C5011%' OR d20 LIKE '%C50111%' OR d20 LIKE '%C50112%' OR d20 LIKE '%C50119%' OR d20 LIKE '%C5012%' OR d20 LIKE '%C50121%' OR d20 LIKE '%C50122%' OR d20 LIKE '%C50129%' OR d20 LIKE '%C502%' OR d20 LIKE '%C5021%' OR d20 LIKE '%C50211%' OR d20 LIKE '%C50212%' OR d20 LIKE '%C50219%' OR d20 LIKE '%C5022%' OR d20 LIKE '%C50221%' OR d20 LIKE '%C50222%' OR d20 LIKE '%C50229%' OR d20 LIKE '%C503%' OR d20 LIKE '%C5031%' OR d20 LIKE '%C50311%' OR d20 LIKE '%C50312%' OR d20 LIKE '%C50319%' OR d20 LIKE '%C5032%' OR d20 LIKE '%C50321%' OR d20 LIKE '%C50322%' OR d20 LIKE '%C50329%' OR d20 LIKE '%C504%' OR d20 LIKE '%C5041%' OR d20 LIKE '%C50411%' OR d20 LIKE '%C50412%' OR d20 LIKE '%C50419%' OR d20 LIKE '%C5042%' OR d20 LIKE '%C50421%' OR d20 LIKE '%C50422%' OR d20 LIKE '%C50429%' OR d20 LIKE '%C505%' OR d20 LIKE '%C5051%' OR d20 LIKE '%C50511%' OR d20 LIKE '%C50512%' OR d20 LIKE '%C50519%' OR d20 LIKE '%C5052%' OR d20 LIKE '%C50521%' OR d20 LIKE '%C50522%' OR d20 LIKE '%C50529%' OR d20 LIKE '%C506%' OR d20 LIKE '%C5061%' OR d20 LIKE '%C50611%' OR d20 LIKE '%C50612%' OR d20 LIKE '%C50619%' OR d20 LIKE '%C5062%' OR d20 LIKE '%C50621%' OR d20 LIKE '%C50622%' OR d20 LIKE '%C50629%' OR d20 LIKE '%C508%' OR d20 LIKE '%C5081%' OR d20 LIKE '%C50811%' OR d20 LIKE '%C50812%' OR d20 LIKE '%C50819%' OR d20 LIKE '%C5082%' OR d20 LIKE '%C50821%' OR d20 LIKE '%C50822%' OR d20 LIKE '%C50829%' OR d20 LIKE '%C509%' OR d20 LIKE '%C5091%' OR d20 LIKE '%C50911%' OR d20 LIKE '%C50912%' OR d20 LIKE '%C50919%' OR d20 LIKE '%C5092%' OR d20 LIKE '%C50921%' OR d20 LIKE '%C50922%' OR d20 LIKE '%C50929%' OR d21 LIKE '%C50%' OR d21 LIKE '%C500%' OR d21 LIKE '%C5001%' OR d21 LIKE '%C50011%' OR d21 LIKE '%C50012%' OR d21 LIKE '%C50019%' OR d21 LIKE '%C5002%' OR d21 LIKE '%C50021%' OR d21 LIKE '%C50022%' OR d21 LIKE '%C50029%' OR d21 LIKE '%C501%' OR d21 LIKE '%C5011%' OR d21 ...
# SELECT DISTINCT d3 FROM TOTFBE WHERE d25 LIKE '%C50%' OR d25 LIKE '%C500%' OR d25 LIKE '%C5001%' OR d25 LIKE '%C50011%' OR d25 LIKE '%C50012%' OR d25 LIKE '%C50019%' OR d25 LIKE '%C5002%' OR d25 LIKE '%C50021%' OR d25 LIKE '%C50022%' OR d25 LIKE '%C50029%' OR d25 LIKE '%C501%' OR d25 LIKE '%C5011%' OR d25 LIKE '%C50111%' OR d25 LIKE '%C50112%' OR d25 LIKE '%C50119%' OR d25 LIKE '%C5012%' OR d25 LIKE '%C50121%' OR d25 LIKE '%C50122%' OR d25 LIKE '%C50129%' OR d25 LIKE '%C502%' OR d25 LIKE '%C5021%' OR d25 LIKE '%C50211%' OR d25 LIKE '%C50212%' OR d25 LIKE '%C50219%' OR d25 LIKE '%C5022%' OR d25 LIKE '%C50221%' OR d25 LIKE '%C50222%' OR d25 LIKE '%C50229%' OR d25 LIKE '%C503%' OR d25 LIKE '%C5031%' OR d25 LIKE '%C50311%' OR d25 LIKE '%C50312%' OR d25 LIKE '%C50319%' OR d25 LIKE '%C5032%' OR d25 LIKE '%C50321%' OR d25 LIKE '%C50322%' OR d25 LIKE '%C50329%' OR d25 LIKE '%C504%' OR d25 LIKE '%C5041%' OR d25 LIKE '%C50411%' OR d25 LIKE '%C50412%' OR d25 LIKE '%C50419%' OR d25 LIKE '%C5042%' OR d25 LIKE '%C50421%' OR d25 LIKE '%C50422%' OR d25 LIKE '%C50429%' OR d25 LIKE '%C505%' OR d25 LIKE '%C5051%' OR d25 LIKE '%C50511%' OR d25 LIKE '%C50512%' OR d25 LIKE '%C50519%' OR d25 LIKE '%C5052%' OR d25 LIKE '%C50521%' OR d25 LIKE '%C50522%' OR d25 LIKE '%C50529%' OR d25 LIKE '%C506%' OR d25 LIKE '%C5061%' OR d25 LIKE '%C50611%' OR d25 LIKE '%C50612%' OR d25 LIKE '%C50619%' OR d25 LIKE '%C5062%' OR d25 LIKE '%C50621%' OR d25 LIKE '%C50622%' OR d25 LIKE '%C50629%' OR d25 LIKE '%C508%' OR d25 LIKE '%C5081%' OR d25 LIKE '%C50811%' OR d25 LIKE '%C50812%' OR d25 LIKE '%C50819%' OR d25 LIKE '%C5082%' OR d25 LIKE '%C50821%' OR d25 LIKE '%C50822%' OR d25 LIKE '%C50829%' OR d25 LIKE '%C509%' OR d25 LIKE '%C5091%' OR d25 LIKE '%C50911%' OR d25 LIKE '%C50912%' OR d25 LIKE '%C50919%' OR d25 LIKE '%C5092%' OR d25 LIKE '%C50921%' OR d25 LIKE '%C50922%' OR d25 LIKE '%C50929%' OR d26 LIKE '%C50%' OR d26 LIKE '%C500%' OR d26 LIKE '%C5001%' OR d26 LIKE '%C50011%' OR d26 LIKE '%C50012%' OR d26 LIKE '%C50019%' OR d26 LIKE '%C5002%' OR d26 LIKE '%C50021%' OR d26 LIKE '%C50022%' OR d26 LIKE '%C50029%' OR d26 LIKE '%C501%' OR d26 LIKE '%C5011%' OR d26 LIKE '%C50111%' OR d26 LIKE '%C50112%' OR d26 LIKE '%C50119%' OR d26 LIKE '%C5012%' OR d26 LIKE '%C50121%' OR d26 LIKE '%C50122%' OR d26 LIKE '%C50129%' OR d26 LIKE '%C502%' OR d26 LIKE '%C5021%' OR d26 LIKE '%C50211%' OR d26 LIKE '%C50212%' OR d26 LIKE '%C50219%' OR d26 LIKE '%C5022%' OR d26 LIKE '%C50221%' OR d26 LIKE '%C50222%' OR d26 LIKE '%C50229%' OR d26 LIKE '%C503%' OR d26 LIKE '%C5031%' OR d26 LIKE '%C50311%' OR d26 LIKE '%C50312%' OR d26 LIKE '%C50319%' OR d26 LIKE '%C5032%' OR d26 LIKE '%C50321%' OR d26 LIKE '%C50322%' OR d26 LIKE '%C50329%' OR d26 LIKE '%C504%' OR d26 LIKE '%C5041%' OR d26 LIKE '%C50411%' OR d26 LIKE '%C50412%' OR d26 LIKE '%C50419%' OR d26 LIKE '%C5042%' OR d26 LIKE '%C50421%' OR d26 LIKE '%C50422%' OR d26 LIKE '%C50429%' OR d26 LIKE '%C505%' OR d26 LIKE '%C5051%' OR d26 LIKE '%C50511%' OR d26 LIKE '%C50512%' OR d26 LIKE '%C50519%' OR d26 LIKE '%C5052%' OR d26 LIKE '%C50521%' OR d26 LIKE '%C50522%' OR d26 LIKE '%C50529%' OR d26 LIKE '%C506%' OR d26 LIKE '%C5061%' OR d26 LIKE '%C50611%' OR d26 LIKE '%C50612%' OR d26 LIKE '%C50619%' OR d26 LIKE '%C5062%' OR d26 LIKE '%C50621%' OR d26 LIKE '%C50622%' OR d26 LIKE '%C50629%' OR d26 LIKE '%C508%' OR d26 LIKE '%C5081%' OR d26 LIKE '%C50811%' OR d26 LIKE '%C50812%' OR d26 LIKE '%C50819%' OR d26 LIKE '%C5082%' OR d26 LIKE '%C50821%' OR d26 LIKE '%C50822%' OR d26 LIKE '%C50829%' OR d26 LIKE '%C509%' OR d26 LIKE '%C5091%' OR d26 LIKE '%C50911%' OR d26 LIKE '%C50912%' OR d26 LIKE '%C50919%' OR d26 LIKE '%C5092%' OR d26 LIKE '%C50921%' OR d26 LIKE '%C50922%' OR d26 LIKE '%C50929%' OR d27 LIKE '%C50%' OR d27 LIKE '%C500%' OR d27 LIKE '%C5001%' OR d27 LIKE '%C50011%' OR d27 LIKE '%C50012%' OR d27 LIKE '%C50019%' OR d27 LIKE '%C5002%' OR d27 LIKE '%C50021%' OR d27 LIKE '%C50022%' OR d27 LIKE '%C50029%' OR d27 LIKE '%C501%' OR d27 LIKE '%C5011%' OR d27 ...
# SELECT DISTINCT id FROM CRLF WHERE site LIKE '%C33%' OR site LIKE '%C34%' OR site LIKE '%C340%' OR site LIKE '%C3400%' OR site LIKE '%C3401%' OR site LIKE '%C3402%' OR site LIKE '%C341%' OR site LIKE '%C3410%' OR site LIKE '%C3411%' OR site LIKE '%C3412%' OR site LIKE '%C342%' OR site LIKE '%C343%' OR site LIKE '%C3430%' OR site LIKE '%C3431%' OR site LIKE '%C3432%' OR site LIKE '%C348%' OR site LIKE '%C3480%' OR site LIKE '%C3481%' OR site LIKE '%C3482%' OR site LIKE '%C349%' OR site LIKE '%C3490%' OR site LIKE '%C3491%' OR site LIKE '%C3492%'
# SELECT DISTINCT d3 FROM TOTFAE WHERE d19 LIKE '%C33%' OR d19 LIKE '%C34%' OR d19 LIKE '%C340%' OR d19 LIKE '%C3400%' OR d19 LIKE '%C3401%' OR d19 LIKE '%C3402%' OR d19 LIKE '%C341%' OR d19 LIKE '%C3410%' OR d19 LIKE '%C3411%' OR d19 LIKE '%C3412%' OR d19 LIKE '%C342%' OR d19 LIKE '%C343%' OR d19 LIKE '%C3430%' OR d19 LIKE '%C3431%' OR d19 LIKE '%C3432%' OR d19 LIKE '%C348%' OR d19 LIKE '%C3480%' OR d19 LIKE '%C3481%' OR d19 LIKE '%C3482%' OR d19 LIKE '%C349%' OR d19 LIKE '%C3490%' OR d19 LIKE '%C3491%' OR d19 LIKE '%C3492%' OR d20 LIKE '%C33%' OR d20 LIKE '%C34%' OR d20 LIKE '%C340%' OR d20 LIKE '%C3400%' OR d20 LIKE '%C3401%' OR d20 LIKE '%C3402%' OR d20 LIKE '%C341%' OR d20 LIKE '%C3410%' OR d20 LIKE '%C3411%' OR d20 LIKE '%C3412%' OR d20 LIKE '%C342%' OR d20 LIKE '%C343%' OR d20 LIKE '%C3430%' OR d20 LIKE '%C3431%' OR d20 LIKE '%C3432%' OR d20 LIKE '%C348%' OR d20 LIKE '%C3480%' OR d20 LIKE '%C3481%' OR d20 LIKE '%C3482%' OR d20 LIKE '%C349%' OR d20 LIKE '%C3490%' OR d20 LIKE '%C3491%' OR d20 LIKE '%C3492%' OR d21 LIKE '%C33%' OR d21 LIKE '%C34%' OR d21 LIKE '%C340%' OR d21 LIKE '%C3400%' OR d21 LIKE '%C3401%' OR d21 LIKE '%C3402%' OR d21 LIKE '%C341%' OR d21 LIKE '%C3410%' OR d21 LIKE '%C3411%' OR d21 LIKE '%C3412%' OR d21 LIKE '%C342%' OR d21 LIKE '%C343%' OR d21 LIKE '%C3430%' OR d21 LIKE '%C3431%' OR d21 LIKE '%C3432%' OR d21 LIKE '%C348%' OR d21 LIKE '%C3480%' OR d21 LIKE '%C3481%' OR d21 LIKE '%C3482%' OR d21 LIKE '%C349%' OR d21 LIKE '%C3490%' OR d21 LIKE '%C3491%' OR d21 LIKE '%C3492%' OR d22 LIKE '%C33%' OR d22 LIKE '%C34%' OR d22 LIKE '%C340%' OR d22 LIKE '%C3400%' OR d22 LIKE '%C3401%' OR d22 LIKE '%C3402%' OR d22 LIKE '%C341%' OR d22 LIKE '%C3410%' OR d22 LIKE '%C3411%' OR d22 LIKE '%C3412%' OR d22 LIKE '%C342%' OR d22 LIKE '%C343%' OR d22 LIKE '%C3430%' OR d22 LIKE '%C3431%' OR d22 LIKE '%C3432%' OR d22 LIKE '%C348%' OR d22 LIKE '%C3480%' OR d22 LIKE '%C3481%' OR d22 LIKE '%C3482%' OR d22 LIKE '%C349%' OR d22 LIKE '%C3490%' OR d22 LIKE '%C3491%' OR d22 LIKE '%C3492%' OR d23 LIKE '%C33%' OR d23 LIKE '%C34%' OR d23 LIKE '%C340%' OR d23 LIKE '%C3400%' OR d23 LIKE '%C3401%' OR d23 LIKE '%C3402%' OR d23 LIKE '%C341%' OR d23 LIKE '%C3410%' OR d23 LIKE '%C3411%' OR d23 LIKE '%C3412%' OR d23 LIKE '%C342%' OR d23 LIKE '%C343%' OR d23 LIKE '%C3430%' OR d23 LIKE '%C3431%' OR d23 LIKE '%C3432%' OR d23 LIKE '%C348%' OR d23 LIKE '%C3480%' OR d23 LIKE '%C3481%' OR d23 LIKE '%C3482%' OR d23 LIKE '%C349%' OR d23 LIKE '%C3490%' OR d23 LIKE '%C3491%' OR d23 LIKE '%C3492%'
# SELECT DISTINCT d3 FROM TOTFBE WHERE d25 LIKE '%C33%' OR d25 LIKE '%C34%' OR d25 LIKE '%C340%' OR d25 LIKE '%C3400%' OR d25 LIKE '%C3401%' OR d25 LIKE '%C3402%' OR d25 LIKE '%C341%' OR d25 LIKE '%C3410%' OR d25 LIKE '%C3411%' OR d25 LIKE '%C3412%' OR d25 LIKE '%C342%' OR d25 LIKE '%C343%' OR d25 LIKE '%C3430%' OR d25 LIKE '%C3431%' OR d25 LIKE '%C3432%' OR d25 LIKE '%C348%' OR d25 LIKE '%C3480%' OR d25 LIKE '%C3481%' OR d25 LIKE '%C3482%' OR d25 LIKE '%C349%' OR d25 LIKE '%C3490%' OR d25 LIKE '%C3491%' OR d25 LIKE '%C3492%' OR d26 LIKE '%C33%' OR d26 LIKE '%C34%' OR d26 LIKE '%C340%' OR d26 LIKE '%C3400%' OR d26 LIKE '%C3401%' OR d26 LIKE '%C3402%' OR d26 LIKE '%C341%' OR d26 LIKE '%C3410%' OR d26 LIKE '%C3411%' OR d26 LIKE '%C3412%' OR d26 LIKE '%C342%' OR d26 LIKE '%C343%' OR d26 LIKE '%C3430%' OR d26 LIKE '%C3431%' OR d26 LIKE '%C3432%' OR d26 LIKE '%C348%' OR d26 LIKE '%C3480%' OR d26 LIKE '%C3481%' OR d26 LIKE '%C3482%' OR d26 LIKE '%C349%' OR d26 LIKE '%C3490%' OR d26 LIKE '%C3491%' OR d26 LIKE '%C3492%' OR d27 LIKE '%C33%' OR d27 LIKE '%C34%' OR d27 LIKE '%C340%' OR d27 LIKE '%C3400%' OR d27 LIKE '%C3401%' OR d27 LIKE '%C3402%' OR d27 LIKE '%C341%' OR d27 LIKE '%C3410%' OR d27 LIKE '%C3411%' OR d27 LIKE '%C3412%' OR d27 LIKE '%C342%' OR d27 LIKE '%C343%' OR d27 LIKE '%C3430%' OR d27 LIKE '%C3431%' OR d27 LIKE '%C3432%' OR d27 LIKE '%C348%' OR d27 LIKE '%C3480%' OR d27 LIKE '%C3481%' OR d27 LIKE '%C3482%' OR d27 LIKE '%C349%' OR d27 LIKE '%C3490%' OR d27 LIKE '%C3491%' OR d27 LIKE '%C3492%' OR d28 LIKE '%C33%' OR d28 LIKE '%C34%' OR d28 LIKE '%C340%' OR d28 LIKE '%C3400%' OR d28 LIKE '%C3401%' OR d28 LIKE '%C3402%' OR d28 LIKE '%C341%' OR d28 LIKE '%C3410%' OR d28 LIKE '%C3411%' OR d28 LIKE '%C3412%' OR d28 LIKE '%C342%' OR d28 LIKE '%C343%' OR d28 LIKE '%C3430%' OR d28 LIKE '%C3431%' OR d28 LIKE '%C3432%' OR d28 LIKE '%C348%' OR d28 LIKE '%C3480%' OR d28 LIKE '%C3481%' OR d28 LIKE '%C3482%' OR d28 LIKE '%C349%' OR d28 LIKE '%C3490%' OR d28 LIKE '%C3491%' OR d28 LIKE '%C3492%' OR d29 LIKE '%C33%' OR d29 LIKE '%C34%' OR d29 LIKE '%C340%' OR d29 LIKE '%C3400%' OR d29 LIKE '%C3401%' OR d29 LIKE '%C3402%' OR d29 LIKE '%C341%' OR d29 LIKE '%C3410%' OR d29 LIKE '%C3411%' OR d29 LIKE '%C3412%' OR d29 LIKE '%C342%' OR d29 LIKE '%C343%' OR d29 LIKE '%C3430%' OR d29 LIKE '%C3431%' OR d29 LIKE '%C3432%' OR d29 LIKE '%C348%' OR d29 LIKE '%C3480%' OR d29 LIKE '%C3481%' OR d29 LIKE '%C3482%' OR d29 LIKE '%C349%' OR d29 LIKE '%C3490%' OR d29 LIKE '%C3491%' OR d29 LIKE '%C3492%'
# SELECT DISTINCT id FROM CRLF WHERE site LIKE '%C16%' OR site LIKE '%C160%' OR site LIKE '%C161%' OR site LIKE '%C162%' OR site LIKE '%C163%' OR site LIKE '%C164%' OR site LIKE '%C165%' OR site LIKE '%C166%' OR site LIKE '%C168%' OR site LIKE '%C169%'
# SELECT DISTINCT d3 FROM TOTFAE WHERE d19 LIKE '%C16%' OR d19 LIKE '%C160%' OR d19 LIKE '%C161%' OR d19 LIKE '%C162%' OR d19 LIKE '%C163%' OR d19 LIKE '%C164%' OR d19 LIKE '%C165%' OR d19 LIKE '%C166%' OR d19 LIKE '%C168%' OR d19 LIKE '%C169%' OR d20 LIKE '%C16%' OR d20 LIKE '%C160%' OR d20 LIKE '%C161%' OR d20 LIKE '%C162%' OR d20 LIKE '%C163%' OR d20 LIKE '%C164%' OR d20 LIKE '%C165%' OR d20 LIKE '%C166%' OR d20 LIKE '%C168%' OR d20 LIKE '%C169%' OR d21 LIKE '%C16%' OR d21 LIKE '%C160%' OR d21 LIKE '%C161%' OR d21 LIKE '%C162%' OR d21 LIKE '%C163%' OR d21 LIKE '%C164%' OR d21 LIKE '%C165%' OR d21 LIKE '%C166%' OR d21 LIKE '%C168%' OR d21 LIKE '%C169%' OR d22 LIKE '%C16%' OR d22 LIKE '%C160%' OR d22 LIKE '%C161%' OR d22 LIKE '%C162%' OR d22 LIKE '%C163%' OR d22 LIKE '%C164%' OR d22 LIKE '%C165%' OR d22 LIKE '%C166%' OR d22 LIKE '%C168%' OR d22 LIKE '%C169%' OR d23 LIKE '%C16%' OR d23 LIKE '%C160%' OR d23 LIKE '%C161%' OR d23 LIKE '%C162%' OR d23 LIKE '%C163%' OR d23 LIKE '%C164%' OR d23 LIKE '%C165%' OR d23 LIKE '%C166%' OR d23 LIKE '%C168%' OR d23 LIKE '%C169%'
# SELECT DISTINCT d3 FROM TOTFBE WHERE d25 LIKE '%C16%' OR d25 LIKE '%C160%' OR d25 LIKE '%C161%' OR d25 LIKE '%C162%' OR d25 LIKE '%C163%' OR d25 LIKE '%C164%' OR d25 LIKE '%C165%' OR d25 LIKE '%C166%' OR d25 LIKE '%C168%' OR d25 LIKE '%C169%' OR d26 LIKE '%C16%' OR d26 LIKE '%C160%' OR d26 LIKE '%C161%' OR d26 LIKE '%C162%' OR d26 LIKE '%C163%' OR d26 LIKE '%C164%' OR d26 LIKE '%C165%' OR d26 LIKE '%C166%' OR d26 LIKE '%C168%' OR d26 LIKE '%C169%' OR d27 LIKE '%C16%' OR d27 LIKE '%C160%' OR d27 LIKE '%C161%' OR d27 LIKE '%C162%' OR d27 LIKE '%C163%' OR d27 LIKE '%C164%' OR d27 LIKE '%C165%' OR d27 LIKE '%C166%' OR d27 LIKE '%C168%' OR d27 LIKE '%C169%' OR d28 LIKE '%C16%' OR d28 LIKE '%C160%' OR d28 LIKE '%C161%' OR d28 LIKE '%C162%' OR d28 LIKE '%C163%' OR d28 LIKE '%C164%' OR d28 LIKE '%C165%' OR d28 LIKE '%C166%' OR d28 LIKE '%C168%' OR d28 LIKE '%C169%' OR d29 LIKE '%C16%' OR d29 LIKE '%C160%' OR d29 LIKE '%C161%' OR d29 LIKE '%C162%' OR d29 LIKE '%C163%' OR d29 LIKE '%C164%' OR d29 LIKE '%C165%' OR d29 LIKE '%C166%' OR d29 LIKE '%C168%' OR d29 LIKE '%C169%'
# SELECT DISTINCT id FROM CRLF WHERE site LIKE '%C15%' OR site LIKE '%C153%' OR site LIKE '%C154%' OR site LIKE '%C155%' OR site LIKE '%C158%' OR site LIKE '%C159%'
# SELECT DISTINCT d3 FROM TOTFAE WHERE d19 LIKE '%C15%' OR d19 LIKE '%C153%' OR d19 LIKE '%C154%' OR d19 LIKE '%C155%' OR d19 LIKE '%C158%' OR d19 LIKE '%C159%' OR d20 LIKE '%C15%' OR d20 LIKE '%C153%' OR d20 LIKE '%C154%' OR d20 LIKE '%C155%' OR d20 LIKE '%C158%' OR d20 LIKE '%C159%' OR d21 LIKE '%C15%' OR d21 LIKE '%C153%' OR d21 LIKE '%C154%' OR d21 LIKE '%C155%' OR d21 LIKE '%C158%' OR d21 LIKE '%C159%' OR d22 LIKE '%C15%' OR d22 LIKE '%C153%' OR d22 LIKE '%C154%' OR d22 LIKE '%C155%' OR d22 LIKE '%C158%' OR d22 LIKE '%C159%' OR d23 LIKE '%C15%' OR d23 LIKE '%C153%' OR d23 LIKE '%C154%' OR d23 LIKE '%C155%' OR d23 LIKE '%C158%' OR d23 LIKE '%C159%'
# SELECT DISTINCT d3 FROM TOTFBE WHERE d25 LIKE '%C15%' OR d25 LIKE '%C153%' OR d25 LIKE '%C154%' OR d25 LIKE '%C155%' OR d25 LIKE '%C158%' OR d25 LIKE '%C159%' OR d26 LIKE '%C15%' OR d26 LIKE '%C153%' OR d26 LIKE '%C154%' OR d26 LIKE '%C155%' OR d26 LIKE '%C158%' OR d26 LIKE '%C159%' OR d27 LIKE '%C15%' OR d27 LIKE '%C153%' OR d27 LIKE '%C154%' OR d27 LIKE '%C155%' OR d27 LIKE '%C158%' OR d27 LIKE '%C159%' OR d28 LIKE '%C15%' OR d28 LIKE '%C153%' OR d28 LIKE '%C154%' OR d28 LIKE '%C155%' OR d28 LIKE '%C158%' OR d28 LIKE '%C159%' OR d29 LIKE '%C15%' OR d29 LIKE '%C153%' OR d29 LIKE '%C154%' OR d29 LIKE '%C155%' OR d29 LIKE '%C158%' OR d29 LIKE '%C159%'
# SELECT DISTINCT id FROM CRLF WHERE site LIKE '%C25%' OR site LIKE '%C250%' OR site LIKE '%C251%' OR site LIKE '%C252%' OR site LIKE '%C253%' OR site LIKE '%C254%' OR site LIKE '%C257%' OR site LIKE '%C258%' OR site LIKE '%C259%'
# SELECT DISTINCT d3 FROM TOTFAE WHERE d19 LIKE '%C25%' OR d19 LIKE '%C250%' OR d19 LIKE '%C251%' OR d19 LIKE '%C252%' OR d19 LIKE '%C253%' OR d19 LIKE '%C254%' OR d19 LIKE '%C257%' OR d19 LIKE '%C258%' OR d19 LIKE '%C259%' OR d20 LIKE '%C25%' OR d20 LIKE '%C250%' OR d20 LIKE '%C251%' OR d20 LIKE '%C252%' OR d20 LIKE '%C253%' OR d20 LIKE '%C254%' OR d20 LIKE '%C257%' OR d20 LIKE '%C258%' OR d20 LIKE '%C259%' OR d21 LIKE '%C25%' OR d21 LIKE '%C250%' OR d21 LIKE '%C251%' OR d21 LIKE '%C252%' OR d21 LIKE '%C253%' OR d21 LIKE '%C254%' OR d21 LIKE '%C257%' OR d21 LIKE '%C258%' OR d21 LIKE '%C259%' OR d22 LIKE '%C25%' OR d22 LIKE '%C250%' OR d22 LIKE '%C251%' OR d22 LIKE '%C252%' OR d22 LIKE '%C253%' OR d22 LIKE '%C254%' OR d22 LIKE '%C257%' OR d22 LIKE '%C258%' OR d22 LIKE '%C259%' OR d23 LIKE '%C25%' OR d23 LIKE '%C250%' OR d23 LIKE '%C251%' OR d23 LIKE '%C252%' OR d23 LIKE '%C253%' OR d23 LIKE '%C254%' OR d23 LIKE '%C257%' OR d23 LIKE '%C258%' OR d23 LIKE '%C259%'
# SELECT DISTINCT d3 FROM TOTFBE WHERE d25 LIKE '%C25%' OR d25 LIKE '%C250%' OR d25 LIKE '%C251%' OR d25 LIKE '%C252%' OR d25 LIKE '%C253%' OR d25 LIKE '%C254%' OR d25 LIKE '%C257%' OR d25 LIKE '%C258%' OR d25 LIKE '%C259%' OR d26 LIKE '%C25%' OR d26 LIKE '%C250%' OR d26 LIKE '%C251%' OR d26 LIKE '%C252%' OR d26 LIKE '%C253%' OR d26 LIKE '%C254%' OR d26 LIKE '%C257%' OR d26 LIKE '%C258%' OR d26 LIKE '%C259%' OR d27 LIKE '%C25%' OR d27 LIKE '%C250%' OR d27 LIKE '%C251%' OR d27 LIKE '%C252%' OR d27 LIKE '%C253%' OR d27 LIKE '%C254%' OR d27 LIKE '%C257%' OR d27 LIKE '%C258%' OR d27 LIKE '%C259%' OR d28 LIKE '%C25%' OR d28 LIKE '%C250%' OR d28 LIKE '%C251%' OR d28 LIKE '%C252%' OR d28 LIKE '%C253%' OR d28 LIKE '%C254%' OR d28 LIKE '%C257%' OR d28 LIKE '%C258%' OR d28 LIKE '%C259%' OR d29 LIKE '%C25%' OR d29 LIKE '%C250%' OR d29 LIKE '%C251%' OR d29 LIKE '%C252%' OR d29 LIKE '%C253%' OR d29 LIKE '%C254%' OR d29 LIKE '%C257%' OR d29 LIKE '%C258%' OR d29 LIKE '%C259%'
# SELECT DISTINCT id FROM CRLF WHERE site LIKE '%C17%' OR site LIKE '%C170%' OR site LIKE '%C171%' OR site LIKE '%C172%' OR site LIKE '%C173%' OR site LIKE '%C178%' OR site LIKE '%C179%' OR site LIKE '%C18%' OR site LIKE '%C180%' OR site LIKE '%C181%' OR site LIKE '%C182%' OR site LIKE '%C183%' OR site LIKE '%C184%' OR site LIKE '%C185%' OR site LIKE '%C186%' OR site LIKE '%C187%' OR site LIKE '%C188%' OR site LIKE '%C189%' OR site LIKE '%C19%' OR site LIKE '%C20%' OR site LIKE '%C21%' OR site LIKE '%C210%' OR site LIKE '%C211%' OR site LIKE '%C212%' OR site LIKE '%C218%'
# SELECT DISTINCT d3 FROM TOTFAE WHERE d19 LIKE '%C17%' OR d19 LIKE '%C170%' OR d19 LIKE '%C171%' OR d19 LIKE '%C172%' OR d19 LIKE '%C173%' OR d19 LIKE '%C178%' OR d19 LIKE '%C179%' OR d19 LIKE '%C18%' OR d19 LIKE '%C180%' OR d19 LIKE '%C181%' OR d19 LIKE '%C182%' OR d19 LIKE '%C183%' OR d19 LIKE '%C184%' OR d19 LIKE '%C185%' OR d19 LIKE '%C186%' OR d19 LIKE '%C187%' OR d19 LIKE '%C188%' OR d19 LIKE '%C189%' OR d19 LIKE '%C19%' OR d19 LIKE '%C20%' OR d19 LIKE '%C21%' OR d19 LIKE '%C210%' OR d19 LIKE '%C211%' OR d19 LIKE '%C212%' OR d19 LIKE '%C218%' OR d20 LIKE '%C17%' OR d20 LIKE '%C170%' OR d20 LIKE '%C171%' OR d20 LIKE '%C172%' OR d20 LIKE '%C173%' OR d20 LIKE '%C178%' OR d20 LIKE '%C179%' OR d20 LIKE '%C18%' OR d20 LIKE '%C180%' OR d20 LIKE '%C181%' OR d20 LIKE '%C182%' OR d20 LIKE '%C183%' OR d20 LIKE '%C184%' OR d20 LIKE '%C185%' OR d20 LIKE '%C186%' OR d20 LIKE '%C187%' OR d20 LIKE '%C188%' OR d20 LIKE '%C189%' OR d20 LIKE '%C19%' OR d20 LIKE '%C20%' OR d20 LIKE '%C21%' OR d20 LIKE '%C210%' OR d20 LIKE '%C211%' OR d20 LIKE '%C212%' OR d20 LIKE '%C218%' OR d21 LIKE '%C17%' OR d21 LIKE '%C170%' OR d21 LIKE '%C171%' OR d21 LIKE '%C172%' OR d21 LIKE '%C173%' OR d21 LIKE '%C178%' OR d21 LIKE '%C179%' OR d21 LIKE '%C18%' OR d21 LIKE '%C180%' OR d21 LIKE '%C181%' OR d21 LIKE '%C182%' OR d21 LIKE '%C183%' OR d21 LIKE '%C184%' OR d21 LIKE '%C185%' OR d21 LIKE '%C186%' OR d21 LIKE '%C187%' OR d21 LIKE '%C188%' OR d21 LIKE '%C189%' OR d21 LIKE '%C19%' OR d21 LIKE '%C20%' OR d21 LIKE '%C21%' OR d21 LIKE '%C210%' OR d21 LIKE '%C211%' OR d21 LIKE '%C212%' OR d21 LIKE '%C218%' OR d22 LIKE '%C17%' OR d22 LIKE '%C170%' OR d22 LIKE '%C171%' OR d22 LIKE '%C172%' OR d22 LIKE '%C173%' OR d22 LIKE '%C178%' OR d22 LIKE '%C179%' OR d22 LIKE '%C18%' OR d22 LIKE '%C180%' OR d22 LIKE '%C181%' OR d22 LIKE '%C182%' OR d22 LIKE '%C183%' OR d22 LIKE '%C184%' OR d22 LIKE '%C185%' OR d22 LIKE '%C186%' OR d22 LIKE '%C187%' OR d22 LIKE '%C188%' OR d22 LIKE '%C189%' OR d22 LIKE '%C19%' OR d22 LIKE '%C20%' OR d22 LIKE '%C21%' OR d22 LIKE '%C210%' OR d22 LIKE '%C211%' OR d22 LIKE '%C212%' OR d22 LIKE '%C218%' OR d23 LIKE '%C17%' OR d23 LIKE '%C170%' OR d23 LIKE '%C171%' OR d23 LIKE '%C172%' OR d23 LIKE '%C173%' OR d23 LIKE '%C178%' OR d23 LIKE '%C179%' OR d23 LIKE '%C18%' OR d23 LIKE '%C180%' OR d23 LIKE '%C181%' OR d23 LIKE '%C182%' OR d23 LIKE '%C183%' OR d23 LIKE '%C184%' OR d23 LIKE '%C185%' OR d23 LIKE '%C186%' OR d23 LIKE '%C187%' OR d23 LIKE '%C188%' OR d23 LIKE '%C189%' OR d23 LIKE '%C19%' OR d23 LIKE '%C20%' OR d23 LIKE '%C21%' OR d23 LIKE '%C210%' OR d23 LIKE '%C211%' OR d23 LIKE '%C212%' OR d23 LIKE '%C218%'
# SELECT DISTINCT d3 FROM TOTFBE WHERE d25 LIKE '%C17%' OR d25 LIKE '%C170%' OR d25 LIKE '%C171%' OR d25 LIKE '%C172%' OR d25 LIKE '%C173%' OR d25 LIKE '%C178%' OR d25 LIKE '%C179%' OR d25 LIKE '%C18%' OR d25 LIKE '%C180%' OR d25 LIKE '%C181%' OR d25 LIKE '%C182%' OR d25 LIKE '%C183%' OR d25 LIKE '%C184%' OR d25 LIKE '%C185%' OR d25 LIKE '%C186%' OR d25 LIKE '%C187%' OR d25 LIKE '%C188%' OR d25 LIKE '%C189%' OR d25 LIKE '%C19%' OR d25 LIKE '%C20%' OR d25 LIKE '%C21%' OR d25 LIKE '%C210%' OR d25 LIKE '%C211%' OR d25 LIKE '%C212%' OR d25 LIKE '%C218%' OR d26 LIKE '%C17%' OR d26 LIKE '%C170%' OR d26 LIKE '%C171%' OR d26 LIKE '%C172%' OR d26 LIKE '%C173%' OR d26 LIKE '%C178%' OR d26 LIKE '%C179%' OR d26 LIKE '%C18%' OR d26 LIKE '%C180%' OR d26 LIKE '%C181%' OR d26 LIKE '%C182%' OR d26 LIKE '%C183%' OR d26 LIKE '%C184%' OR d26 LIKE '%C185%' OR d26 LIKE '%C186%' OR d26 LIKE '%C187%' OR d26 LIKE '%C188%' OR d26 LIKE '%C189%' OR d26 LIKE '%C19%' OR d26 LIKE '%C20%' OR d26 LIKE '%C21%' OR d26 LIKE '%C210%' OR d26 LIKE '%C211%' OR d26 LIKE '%C212%' OR d26 LIKE '%C218%' OR d27 LIKE '%C17%' OR d27 LIKE '%C170%' OR d27 LIKE '%C171%' OR d27 LIKE '%C172%' OR d27 LIKE '%C173%' OR d27 LIKE '%C178%' OR d27 LIKE '%C179%' OR d27 LIKE '%C18%' OR d27 LIKE '%C180%' OR d27 LIKE '%C181%' OR d27 LIKE '%C182%' OR d27 LIKE '%C183%' OR d27 LIKE '%C184%' OR d27 LIKE '%C185%' OR d27 LIKE '%C186%' OR d27 LIKE '%C187%' OR d27 LIKE '%C188%' OR d27 LIKE '%C189%' OR d27 LIKE '%C19%' OR d27 LIKE '%C20%' OR d27 LIKE '%C21%' OR d27 LIKE '%C210%' OR d27 LIKE '%C211%' OR d27 LIKE '%C212%' OR d27 LIKE '%C218%' OR d28 LIKE '%C17%' OR d28 LIKE '%C170%' OR d28 LIKE '%C171%' OR d28 LIKE '%C172%' OR d28 LIKE '%C173%' OR d28 LIKE '%C178%' OR d28 LIKE '%C179%' OR d28 LIKE '%C18%' OR d28 LIKE '%C180%' OR d28 LIKE '%C181%' OR d28 LIKE '%C182%' OR d28 LIKE '%C183%' OR d28 LIKE '%C184%' OR d28 LIKE '%C185%' OR d28 LIKE '%C186%' OR d28 LIKE '%C187%' OR d28 LIKE '%C188%' OR d28 LIKE '%C189%' OR d28 LIKE '%C19%' OR d28 LIKE '%C20%' OR d28 LIKE '%C21%' OR d28 LIKE '%C210%' OR d28 LIKE '%C211%' OR d28 LIKE '%C212%' OR d28 LIKE '%C218%' OR d29 LIKE '%C17%' OR d29 LIKE '%C170%' OR d29 LIKE '%C171%' OR d29 LIKE '%C172%' OR d29 LIKE '%C173%' OR d29 LIKE '%C178%' OR d29 LIKE '%C179%' OR d29 LIKE '%C18%' OR d29 LIKE '%C180%' OR d29 LIKE '%C181%' OR d29 LIKE '%C182%' OR d29 LIKE '%C183%' OR d29 LIKE '%C184%' OR d29 LIKE '%C185%' OR d29 LIKE '%C186%' OR d29 LIKE '%C187%' OR d29 LIKE '%C188%' OR d29 LIKE '%C189%' OR d29 LIKE '%C19%' OR d29 LIKE '%C20%' OR d29 LIKE '%C21%' OR d29 LIKE '%C210%' OR d29 LIKE '%C211%' OR d29 LIKE '%C212%' OR d29 LIKE '%C218%'
# SELECT DISTINCT id FROM CRLF WHERE site LIKE '%C23%' OR site LIKE '%for_tuple_fill%'
# SELECT DISTINCT d3 FROM TOTFAE WHERE d19 LIKE '%C23%' OR d19 LIKE '%for_tuple_fill%' OR d20 LIKE '%C23%' OR d20 LIKE '%for_tuple_fill%' OR d21 LIKE '%C23%' OR d21 LIKE '%for_tuple_fill%' OR d22 LIKE '%C23%' OR d22 LIKE '%for_tuple_fill%' OR d23 LIKE '%C23%' OR d23 LIKE '%for_tuple_fill%'
# SELECT DISTINCT d3 FROM TOTFBE WHERE d25 LIKE '%C23%' OR d25 LIKE '%for_tuple_fill%' OR d26 LIKE '%C23%' OR d26 LIKE '%for_tuple_fill%' OR d27 LIKE '%C23%' OR d27 LIKE '%for_tuple_fill%' OR d28 LIKE '%C23%' OR d28 LIKE '%for_tuple_fill%' OR d29 LIKE '%C23%' OR d29 LIKE '%for_tuple_fill%'
#    Group_name CRLF_unique_id TOTFAE_unique_id TOTFBE__unique_id  \
# 0       口腔癌群組              0                0                 0
# 1       白血病群組              0                0                 0
# 2     肝外膽管癌群組              0                0                 0
# 3        肝癌群組              0                0                 0
# 4        乳癌群組             78               77                79
# 5        肺癌群組              1                1                 0
# 6        胃癌群組              0                0                 0
# 7       食道癌群組              1                1                 1
# 8       胰臟癌群組              0                0                 0
# 9        腸癌群組              2                3                 2
# 10      膽囊癌群組              0                0                 0
#
#    MIX_unique_count
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                80
# 5                 1
# 6                 0
# 7                 1
# 8                 0
# 9                 3
# 10                0

# %% [markdown]
# <h1><center>Count版本</center></h1>

# %%
import pandas as pd
import sqlite3

# 連接到現有的 SQLite 資料庫
conn = sqlite3.connect('BiobankData.db')

# 定義群組列表和相應的疾病代碼
group_disease_mapping = {
    '口腔癌群組': ["C00","C000","C001","C002","C003","C004","C005","C006","C008","C009","C01","C02","C020",
              "C021","C022","C023","C024","C028","C029","C03","C030","C031","C039","C04","C040","C041",
              "C048","C049","C05","C050","C051","C052","C058","C059","C06","C060","C061","C062","C068",
              "C0680","C0689","C069","C09","C090","C091","C098","C099","C10","C100","C101","C102","C103",
              "C104","C108","C109","C12","C13","C130","C131","C132","C138","C139","C14","C140","C142","C148"],
    
    '白血病群組': ["C42","C420","C421","C91","C910","C9100","C9101","C9102","C911","C9110","C9111","C9112",
             "C913","C9130","C9131","C9132","C914","C9140","C9141","C9142","C915","C9150","C9151","C9152",
             "C916","C9160","C9161","C9162","C919","C9190","C9191","C9192","C91A","C91A0","C91A1","C91A2",
             "C91Z","C91Z0","C91Z1","C91Z2","C92","C920","C9200","C9201","C9202","C921","C9210","C9211",
             "C9212","C922","C9220","C9221","C9222","C923","C9230","C9231","C9232","C924","C9240","C9241",
             "C9242","C925","C9250","C9251","C9252","C926","C9260","C9261","C9262","C929","C9290","C9291",
             "C9292","C92A","C92A0","C92A1","C92A2","C92Z","C92Z0","C92Z1","C92Z2","C93","C930","C9300",
             "C9301","C9302","C931","C9310","C9311","C9312","C933","C9330","C9331","C9332","C939","C9390",
             "C9391","C9392","C93Z","C93Z0","C93Z1","C93Z2","C94","C940","C9400","C9401","C9402","C942",
             "C9420","C9421","C9422","C943","C9430","C9431","C9432","C944","C9440","C9441","C9442","C946",
             "C948","C9480","C9481","C9482","C95","C950","C9500","C9501","C9502","C951","C9510","C9511",
             "C9512","C959","C9590","C9591","C9592"],
    
    '肝外膽管癌群組': ["C24","C240","C241","C248","C249"],
    
    '肝癌群組': ["C22","C220","C221","C222","C223","C224","C227","C228","C229"],
    
    '乳癌群組': ["C50","C500","C5001","C50011","C50012","C50019","C5002","C50021","C50022","C50029","C501",
             "C5011","C50111","C50112","C50119","C5012","C50121","C50122","C50129","C502","C5021","C50211",
             "C50212","C50219","C5022","C50221","C50222","C50229","C503","C5031","C50311","C50312","C50319",
             "C5032","C50321","C50322","C50329","C504","C5041","C50411","C50412","C50419","C5042","C50421",
             "C50422","C50429","C505","C5051","C50511","C50512","C50519","C5052","C50521","C50522","C50529",
             "C506","C5061","C50611","C50612","C50619","C5062","C50621","C50622","C50629","C508","C5081",
             "C50811","C50812","C50819","C5082","C50821","C50822","C50829","C509","C5091","C50911","C50912",
             "C50919","C5092","C50921","C50922","C50929"],
    
    '肺癌群組': ["C33","C34","C340","C3400","C3401","C3402","C341","C3410","C3411","C3412","C342","C343","C3430",
             "C3431","C3432","C348","C3480","C3481","C3482","C349","C3490","C3491","C3492"],
    
    '胃癌群組': ["C16","C160","C161","C162","C163","C164","C165","C166","C168","C169"],
    
    '食道癌群組': ["C15","C153","C154","C155","C158","C159"],
    
    '胰臟癌群組': ["C25","C250","C251","C252","C253","C254","C257","C258","C259"],
    
    '腸癌群組': ["C17","C170","C171","C172","C173","C178","C179","C18","C180","C181","C182","C183","C184",
             "C185","C186","C187","C188","C189","C19","C20","C21","C210","C211","C212","C218"],
    
    '膽囊癌群組': ["C23","for_tuple_fill"]

}

def get_unique_ids_and_count(table_name, group_name, disease_codes):
    id_column = None
    other_columns = []

    if table_name == 'CRLF':
        id_column = 'id'
        other_columns = ['site']
    elif table_name == 'TOTFAE':
        id_column = 'd3'
        other_columns = ['d19', 'd20', 'd21', 'd22', 'd23']
    elif table_name == 'TOTFBE':
        id_column = 'd3'
        other_columns = ['d25', 'd26', 'd27', 'd28', 'd29']

    # 建構 SQL 查詢
    query_count = f"SELECT {', '.join([f'{col}' for col in other_columns])}, COUNT(*) as count FROM {table_name} WHERE {' OR '.join([f'{col} IN {tuple(disease_codes)}' for col in other_columns])} GROUP BY {', '.join([f'{col}' for col in other_columns])}"

    # 使用 pd.read_sql_query 讀取结果
    result_count = pd.read_sql_query(query_count, conn)

    # 建構 SQL 查询獲取唯一值
    query_unique = f"SELECT DISTINCT {id_column} FROM {table_name} WHERE {' OR '.join([f'{col} IN {tuple(disease_codes)}' for col in other_columns])}"

    # 使用 pd.read_sql_query 讀取结果
    result_unique = pd.read_sql_query(query_unique, conn)

    return result_unique[id_column], result_count


# 初始化结果 DataFrame
result_df = pd.DataFrame(columns=['Group_name', 'CRLF_unique_id', 'TOTFAE_unique_id', 'TOTFBE_unique_id', 'MIX_unique_id_count', 'CRLF_disease_count', 'TOTFAE_disease_count', 'TOTFBE_disease_count'])

# 查找结果
for group_name, disease_codes in group_disease_mapping.items():
    CRLF_unique_id, CRLF_disease_count = get_unique_ids_and_count('CRLF', group_name, disease_codes)
    TOTFAE_unique_id, TOTFAE_disease_count = get_unique_ids_and_count('TOTFAE', group_name, disease_codes)
    TOTFBE_unique_id, TOTFBE_disease_count = get_unique_ids_and_count('TOTFBE', group_name, disease_codes)
    MIX_unique_id_count = pd.concat([CRLF_unique_id, TOTFAE_unique_id, TOTFBE_unique_id])

    # 將结果添加到结果 DataFrame
    result_df = result_df.append({
        'Group_name': group_name,
        'CRLF_unique_id': len(CRLF_unique_id),
        'TOTFAE_unique_id': len(TOTFAE_unique_id),
        'TOTFBE_unique_id': len(TOTFBE_unique_id),
        'MIX_unique_id_count': MIX_unique_id_count.nunique(),
        'CRLF_disease_count': CRLF_disease_count['count'].sum(),
        'TOTFAE_disease_count': TOTFAE_disease_count['count'].sum(),
        'TOTFBE_disease_count': TOTFBE_disease_count['count'].sum()
    }, ignore_index=True)

# 顯示結果
conn.close()
result_df
# Out:
#    Group_name CRLF_unique_id TOTFAE_unique_id TOTFBE_unique_id  \
# 0       口腔癌群組              0                0                0
# 1       白血病群組              0                0                0
# 2     肝外膽管癌群組              0                0                0
# 3        肝癌群組              0                0                0
# 4        乳癌群組             78               77               79
# 5        肺癌群組              1                1                0
# 6        胃癌群組              0                0                0
# 7       食道癌群組              1                1                1
# 8       胰臟癌群組              0                0                0
# 9        腸癌群組              1                3                2
# 10      膽囊癌群組              0                0                0
#
#    MIX_unique_id_count CRLF_disease_count TOTFAE_disease_count  \
# 0                    0                  0                    0
# 1                    0                  0                    0
# 2                    0                  0                    0
# 3                    0                  0                    0
# 4                   80                 79                 2281
# 5                    1                  1                   20
# 6                    0                  0                    0
# 7                    1                  1                   71
# 8                    0                  0                    0
# 9                    3                  1                   81
# 10                   0                  0                    0
#
#    TOTFBE_disease_count
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                   391
# 5                     0
# 6                     0
# 7                     1
# 8                     0
# 9                    30
# 10                    0
